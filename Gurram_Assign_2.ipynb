# %% [markdown]
# <a href="https://colab.research.google.com/github/VivekRedD1999/Computational-Methods/blob/main/Gurram_Assign_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of the product [Apple iPhone 11](https://www.amazon.com/Apple-iPhone-11-64GB-Unlocked/dp/B07ZPKF8RG/ref=sr_1_13?dchild=1&keywords=iphone+12&qid=1631721363&sr=8-13) on amazon.
#
# (2) Collect the top 10000 User Reviews of the film [Shang-Chi and the Legend of the Ten Rings](https://www.imdb.com/title/tt9376612/reviews?ref_=tt_sa_3) from IMDB.
#
# (3) Collect all the reviews of the top 100 most popular software from [G2](https://www.g2.com/) or [Capterra](https://www.capterra.com/)
#
# (4) Collect the abstracts of the top 10000 research papers by using the query [natural language processing](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlv&t=doc) from CiteSeerX.
#
# (5) Collect all the information of the 904 narrators in the [Densho Digital Repository](https://ddr.densho.org/narrators/).
#
# (6) Collect the top 10000 tweets by using hashtag ["#blacklivesmatter"](https://twitter.com/hashtag/blacklivesmatter) from Twitter.

# %%
# Write your code here

from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = "https://www.imdb.com/title/tt9376612/reviews?ref_=tt_sa_10000"
page = requests.get(url)
pa_Content = page.text
soup = BeautifulSoup(pa_Content, 'html.parser')

# %%
imdb_reviews=[]
right_table=soup.find('div', {'class':"lister"})
#right_table = soup.find('div', id="cm-cr-dp-review-list")
for i in right_table.findAll('div', class_="lister-item mode-detail imdb-user-review collapsable"):
  imdb_reviews.append(i.find("div", class_="text show-more__control"))

# %%
#df = pd.DataFrame({'User Reviews': imdb_reviews})

#save the dataframe on a csv file
#df.to_csv('userReviews.csv')

# %%
# Out:
# ['']

# %%
print(imdb_reviews)
# Out:
# [<div class="text show-more__control">I got to admit I wasn't particularly blown away by anything in the movie.. I might even say "I was bored" by it.<br/><br/>Don't get me wrong.. it IS a spectacle! The action is great. The locations are nice, costume design, sound design, etc. But it is overall a soft release not worth seeing in theaters.. specially as a follow-up to what Endgame was.<br/><br/>The biggest problem for me, is how the underwritten lead has muddled personality (for reasons covered in the story) devoid of charm, personality or good dialogue.<br/><br/>The next issue is the humor, which didn't land for me.. Not once. The supporting lead Awkwafina isn't her normal "loud" self that's supposed to be funny every time she opens her mouth. Her role is very supportive and a little dramatic. And while I questioned myself why was she even there for, it doesn't ultimately matter. She is another forgettable character that is given more importance than the role deserves.<br/><br/>Finally, the third act is weak. There's a balancing problem with stakes. You can't feel tension or weight to any action. And there's a lot of superficial "I can't do it" until they can.<br/><br/>In the end, this feels like a very safe plot, written in a way to appeal to china (considering how the Mandarin is portrayed), that ends up appealing to no one specific. Certainly doesn't feel like a Marvel movie.. but it was bound to happen if we are to be introduced to different aspects of the narrative. But it also doesn't feel like a comic book. It's more generic than that.</div>, <div class="text show-more__control">The characters are a bit incoherent and straight up contradict their own characterizations at times, because the plot needs them to do it. There are a bunch of unneeded "deux-ex machina" or conveniences because the writers trapped themselves into corners for no reason (that's what happens when you get the 2021 "Mortal Kombat", "WW84" and "The Expendables" writers).<br/><br/>Also, we have Awkwafina destroying every type of scene (dramatic; epic; and also the comedic ones) with one of the worst "acting" I've ever seen and a same type of joke ("awkward nonsense") over and over, from start to finish, with a role ridiculously large for a dumb comic relief.<br/><br/>But... Liu is actually pretty good as a lead (and his character is potentially great), and the "Shang-Chi world" is beautiful and it has everything to be super fun to watch in the future...without Awkwafine and better writers.</div>, <div class="text show-more__control">Destin Daniel Cretton's 'Shang-Chi and the Legend of the Ten Rings' marks a bland start to the new phase of Marvel Cinematic Universe. It is a spectacle with regards to action sequence and fighting choreography, but the film misses a solid storyline for an origin story as its titular character lacks personality and does not go through any heroic transformation story arc. Simu Liu has a strong presence as Shang-Chi, yet he is overshadowed by many of his more experienced co-stars.</div>, <div class="text show-more__control">The story was riddled with holes and plot issues. Since when does Awkwafina's pedestrian character all of a sudden get invited to become part of the MCU team? What's her super power... stupidity? Don't get me wrong, I love her, but her character was lazily written. Then there's the whole daddy issues dynamic - Shang is with him, then against, then with etc.. Then we have these ridiculous dragons fighting, where one scores some power crystals and becomes stronger! This is just infantile lazy writing. There was zero shock value or anything spectacular in the entire runtime, with tedious long middle acts and a bumbling third act. The jokes were cliched and not funny. The funniest parts were Ben Kingsley's character, (of whom was in this for what reasons??) and the ending to go Karaoke - which was the only time I actually cracked a chuckle. You'd think with three writers we'd have something cohesive and cohe ...
# Language: English
# Source: Hotstar
# RECOMMENDED<br/><br/>The story and making is worth to watch in big screen with good sound system. The first half is filled with great actions and funny moments and it get into serious mode in the second half.<br/><br/>The second half is more traditional and sentimental....the decent story and colourful visual makes this so grand...
# Good movie to watch with family.</div>, <div class="text show-more__control">Martial arts meets the MCU in Shang-Chi and the Legend of the Ten Rings. More Crouching Tiger than Jackie Chan, the plot for the film is kinda hum-drum, the sort of mystical Eastern fantasy cobblers that practically writes itself.<br/><br/>Shang-Chi is the son of immortal, power-hungry warlord Xu Wenwu (Tony Chiu-Wai Leung) and Li (Fala Chen), a warrior woman from the hidden village of Ta Lo. After falling in love with Li and becoming a father, Wenwu gives up his wicked ways and packs away the ten legendary rings that gave him much of his power. However, after his wife is killed by his old enemies, Wenwu once again wears the rings and trains his son to become an assassin. Ashamed of what he has become, Shang-Chi goes into hiding in America and becomes Shaun (Simu Liu), but his past eventually catches up with him when his father sends his army, The Ten Rings, to steal the pendants given to him and his sister Xialing (Meng'er Zhang) by their mother. Wenwu requires both pendants to reveal the way to Ta Lo, where he believes that his wife is being held captive by her people.<br/><br/>This Marvel movie is at its most fun before the plot starts to get in the way and the CGI becomes too overbearing and intrusive: the early fight scenes - a battle on a runaway bus against a henchman known as Razor Fist, and a fight on some high-rise bamboo scaffolding - deliver lots of impressively choreographed action that will please both martial arts fans and superhero addicts. Awkwafina, as Shang-Chi's loyal friend Katy, provides some comic relief, but also gets stuck in with the action.<br/><br/>Unfortunately, the film quickly goes downhill after the good guys make their way to Ta Lo, with a little help from Tony Slattery (see Iron Man 3) and a furry winged creature with no face. The inevitable battle between the villagers and Wenwu's army is typical overblown Marvel mayhem, but the massive CGI tsunami arrives when Wenwu opens the inter-dimensional gate that he thinks is holding Li prisoner: instead of releasing his wife, he frees a swarm of flying tentacled soul-suckers and their big bad boss The Dweller. Fortunately for the Ta Lo people, they have a massive magical dragon on their side, which wakes up and adds to the digital whizz-bangery.<br/><br/>As technically impressive as the special effects are, I found the second half of the film visually overwhelming yet remarkably uninvolving - a whirlwind of pixels and noisy action without much substance.<br/><br/>5/10. It was nice to see HK/Chinese stars Michelle Yeoh, Tony Leung and Yuen Wah together in a Marvel movie; I just wish it had been a better one.</div>, <div class="text show-more__control">Shang-Chi and the Legend of the Ten Rings takes place some time after Avengers Endgame is the beginning of phase four of the marvel cinematic universe.<br/><br/>Shang-Chi is an alright movie. It has some great fight scenes with some incredible fight choreography and epic large-scale battles. It is also has some good comedic scenes that made me laugh a couple of times. Where Shang-Chi suffers is when it comes to the plot. I didn't find the story very compelling and I didn't get that attached to the characters. It's a story that I feel has been done many times before.<br/><br/>Shang-Chi wasn't for me but it's comedy and fight scenes make up for some of it's flaws. If you are familiar with the Marvel franchise I assume you somewhat know what to expect and for you I can recommend it. Although the movie isn't that great, I still think it's good enough to the point of where it's worth watching just to keep up with the larger plot of the MCU. For those not invested in the MCU, I don't believe that this movie is the one you should start with.</div>, <div class="text show-more__control">The best marvel movie after Endgame. The story is a bit cliché but the rest is absolutely amazing. The fight scenes are the best in the MCU in my opinion ...
# I'm getting too old for this s#.t..</div>, <div class="text show-more__control">Really entertaining movie. Actors were great Simu Liu brought it big time he is excellent as the main character. Awkwafina is hilarious and I wish she had more screen time. As far as Marvel movies goes, it's not the best one but still very good.</div>, <div class="text show-more__control">This is the story of ten rings, weapons, used for thousands of years to take power and control. Shang chi ( simu liu, as chang xi ) accidentally gets pulled into the history, and can't turn back. Co-stars awkwafina, tony leung, both winners of TONS of film festival awards. Also ben kingsley... oscar for gandhi. Although he looks so different, you may not recognize kingsley in his role! It's a marvel story, from disney, so there's a good mix of adventure, violence, animation, levitation, and some jokes sprinkled here and there. The bad guys are collecting the pendants with the power, and cannot be allowed to gether them all. Surprisingly, a couple swears, giving it the PG13 rating. They meet good people that want to help them on their journey, and evil people that want to destroy them. Some fun special effects. Directed by destin cretton. Chang xi character created by steve englehart, jim starlin. It's quite good.</div>, <div class="text show-more__control">I really liked that the actors spoke their native language, Mandarin, because it would've felt too Americanized otherwise. But there was something unfinished about this movie and I'm not sure what it is. The pacing was alright, a little too slow or fast at times, and as far as storylines go, it was not as exciting as I thought it would be. The fight scenes were great though, especially the final grand battle scene.</div>, <div class="text show-more__control">This is the worst marvel movie I have seen to date.after seeing the movie I was honestly surprised by all the high ratings. Did we watch the same thing? The movie is without a soul. Characters aren't build up enough even with a 2 hour run time. The movie literally got nothing to do with the ten rings. Movie became Godzilla vs King Kong at the end. Waste of 2 hours. Honestly clueless why people high praised for this movie. What a waste of opportunity to create a wonderful and authentic world for Asian marvel universe.</div>]

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write your code here
import string
import nltk
from nltk.corpus import stopwords


rev = []
for i in imdb_reviews:
  s = str(i)
  x = s.replace(s[:37],"").replace("<br/><br/>","").replace("</div>", "").replace("\n", " ")
  rev.append(x.lower())



def Punctuation(rev):
    punctuation = string.punctuation
    lis = []
    for sentence in rev:
      se=[]
      se.clear()
      for j in sentence:
        #print(j)
        if j in punctuation:
          se.append("")        
        else:
          se.append(j)  
      lis.append("".join(se).replace("i ", ""))
      
       
    return lis
      
def convert_sentence(rev):
  reviews=[]
  for i in rev:
    review.append(i)
  return reviews
        


   
df = pd.DataFrame({'User Reviews': Punctuation(rev) })

#save the dataframe on a csv file
df.to_csv('userReviews.csv')



df["User Reviews"][0][3]
# Out:
# ' '

# %%
import nltk
from nltk.stem import WordNetLemmatizer
#nltk.download('omw-1.4')
lemmatizer = WordNetLemmatizer()
from nltk.stem import PorterStemmer
ps = PorterStemmer()
#nltk.download('stopwords')

nltk.download('punkt')
def Tokenize(rev):
  reviews=[]
  for i in rev:
    nltk_tokens = nltk.word_tokenize(i)
    reviews.append(nltk_tokens)
  return reviews

def Stemming_Lemmetize(rev):
  lem_reviews = []
  for i in rev:
    len_sen=[]
    for j in i:
      len_sen.append(ps.stem(lemmatizer.lemmatize(j)))
    lem_reviews.append(len_sen)
  return lem_reviews

def stop_words(sl):
  stop_words = set(stopwords.words('english'))
  lem_reviews = []
  for i in sl:
    print(i)
    len_sen=[]
    for j in i:
      if j not in stop_words:
        len_sen.append(j)
    lem_reviews.append(len_sen)
  return lem_reviews
  


        

#stop_words(Tokenize(df["User Reviews"]))
#print(Tokenize(df["User Reviews"])[0][0])
Stemming_Lemmetize(stop_words(Tokenize(df["User Reviews"])))
# Out:
# ['got', 'to', 'admit', 'wasnt', 'particularly', 'blown', 'away', 'by', 'anything', 'in', 'the', 'movie', 'might', 'even', 'say', 'was', 'bored', 'by', 'itdont', 'get', 'me', 'wrong', 'it', 'is', 'a', 'spectacle', 'the', 'action', 'is', 'great', 'the', 'locations', 'are', 'nice', 'costume', 'design', 'sound', 'design', 'etc', 'but', 'it', 'is', 'overall', 'a', 'soft', 'release', 'not', 'worth', 'seeing', 'in', 'theaters', 'specially', 'as', 'a', 'followup', 'to', 'what', 'endgame', 'wasthe', 'biggest', 'problem', 'for', 'me', 'is', 'how', 'the', 'underwritten', 'lead', 'has', 'muddled', 'personality', 'for', 'reasons', 'covered', 'in', 'the', 'story', 'devoid', 'of', 'charm', 'personality', 'or', 'good', 'dialoguethe', 'next', 'issue', 'is', 'the', 'humor', 'which', 'didnt', 'land', 'for', 'me', 'not', 'once', 'the', 'supporting', 'lead', 'awkwafina', 'isnt', 'her', 'normal', 'loud', 'self', 'thats', 'supposed', 'to', 'be', 'funny', 'every', 'time', 'she', 'opens', 'her', 'mouth', 'her', 'role', 'is', 'very', 'supportive', 'and', 'a', 'little', 'dramatic', 'and', 'while', 'questioned', 'myself', 'why', 'was', 'she', 'even', 'there', 'for', 'it', 'doesnt', 'ultimately', 'matter', 'she', 'is', 'another', 'forgettable', 'character', 'that', 'is', 'given', 'more', 'importance', 'than', 'the', 'role', 'deservesfinally', 'the', 'third', 'act', 'is', 'weak', 'theres', 'a', 'balancing', 'problem', 'with', 'stakes', 'you', 'cant', 'feel', 'tension', 'or', 'weight', 'to', 'any', 'action', 'and', 'theres', 'a', 'lot', 'of', 'superficial', 'cant', 'do', 'it', 'until', 'they', 'canin', 'the', 'end', 'this', 'feels', 'like', 'a', 'very', 'safe', 'plot', 'written', 'in', 'a', 'way', 'to', 'appeal', 'to', 'china', 'considering', 'how', 'the', 'mandarin', 'is', 'portrayed', 'that', 'ends', 'up', 'appealing', 'to', 'no', 'one', 'specific', 'certainly', 'doesnt', 'feel', 'like', 'a', 'marvel', 'movie', 'but', 'it', 'was', 'bound', 'to', 'happen', 'if', 'we', 'are', 'to', 'be', 'introduced', 'to', 'different', 'aspects', 'of', 'the', 'narrative', 'but', 'it', 'also', 'doesnt', 'feel', 'like', 'a', 'comic', 'book', 'its', 'more', 'generic', 'than', 'that']
# ['the', 'characters', 'are', 'a', 'bit', 'incoherent', 'and', 'straight', 'up', 'contradict', 'their', 'own', 'characterizations', 'at', 'times', 'because', 'the', 'plot', 'needs', 'them', 'to', 'do', 'it', 'there', 'are', 'a', 'bunch', 'of', 'unneeded', 'deuxex', 'machina', 'or', 'conveniences', 'because', 'the', 'writers', 'trapped', 'themselves', 'into', 'corners', 'for', 'no', 'reason', 'thats', 'what', 'happens', 'when', 'you', 'get', 'the', '2021', 'mortal', 'kombat', 'ww84', 'and', 'the', 'expendables', 'writersalso', 'we', 'have', 'awkwafina', 'destroying', 'every', 'type', 'of', 'scene', 'dramatic', 'epic', 'and', 'also', 'the', 'comedic', 'ones', 'with', 'one', 'of', 'the', 'worst', 'acting', 'ive', 'ever', 'seen', 'and', 'a', 'same', 'type', 'of', 'joke', 'awkward', 'nonsense', 'over', 'and', 'over', 'from', 'start', 'to', 'finish', 'with', 'a', 'role', 'ridiculously', 'large', 'for', 'a', 'dumb', 'comic', 'reliefbut', 'liu', 'is', 'actually', 'pretty', 'good', 'as', 'a', 'lead', 'and', 'his', 'character', 'is', 'potentially', 'great', 'and', 'the', 'shangchworld', 'is', 'beautiful', 'and', 'it', 'has', 'everything', 'to', 'be', 'super', 'fun', 'to', 'watch', 'in', 'the', 'futurewithout', 'awkwafine', 'and', 'better', 'writers']
# ['destin', 'daniel', 'crettons', 'shangchand', 'the', 'legend', 'of', 'the', 'ten', 'rings', 'marks', 'a', 'bland', 'start', 'to', 'the', 'new', 'phase', 'of', 'marvel', 'cinematic', 'universe', 'it', 'is', 'a', 'spectacle', 'with', 'regards', 'to', 'action', 'sequence', 'and', 'fighting', 'choreography', 'but', 'the', 'film', 'misses', 'a', 'solid', 'storyline', 'for', 'an', 'origin', 'story', 'as', 'its', 'titular', 'character', 'lacks', 'personality', 'and', 'does', 'not', 'go', 'through', 'any', 'heroic', 'transformation', 'story', 'arc', 'simu', 'liu', 'has', 'a', 'strong', 'presence', 'as', 'shangchyet', 'he', 'is', 'overshadowed', 'by', 'many', 'of', 'his', 'more', 'experienced', 'costars']
# ['the', 'story', 'was', 'riddled', 'with', 'holes', 'and', 'plot', 'issues', 'since', 'when', 'does', 'awkwafinas', 'pedestrian', 'character', 'all', 'of', 'a', 'sudden', 'get', 'invited', 'to', 'become', 'part', 'of', 'the', 'mcu', 'team', 'whats', 'her', 'super', 'power', 'stupidity', 'dont', 'get', 'me', 'wrong', 'love', 'her', 'but', 'her', 'character', 'was', 'lazily', 'written', 'then', 'theres', 'the', 'whole', 'daddy', 'issues', 'dynamic', 'shang', 'is', 'with', 'him', 'then', 'against', 'then', 'with', 'etc', 'then', 'we', 'have', 'these', 'ridiculous', 'dragons', 'fighting', 'where', 'one', 'scores', 'some', 'power', 'crystals', 'and', 'becomes', 'stronger', 'this', 'is', 'just', 'infantile', 'lazy', 'writing', 'there', 'was', 'zero', 'shock', 'value', 'or', 'anything', 'spectacular', 'in', 'the', 'entire', 'runtime', 'with', 'tedious', 'long', 'middle', 'acts', 'and', 'a', 'bumbling', 'third', 'act', 'the', 'jokes', 'were', 'cliched', 'and', 'not', 'funny', 'the', 'funniest', 'parts', 'were', 'ben', 'kingsleys', 'character', 'of', 'whom', 'was', 'in', 'this', 'for', 'what', 'reasons', 'and', 'the', 'ending', 'to', 'go', 'karaoke', 'which', 'was', 'the', 'only', 'time', 'actually', 'cracked', 'a', 'chuckle', 'youd', 'think', 'with', 'three', 'writers', 'wed', 'have', 'something', 'cohesive', 'and', 'coherent', 'but', 'instead', 'of', 'a', 'marvel', 'superhero', 'story', 'we', 'got', 'a', 'disney', 'evil', 'vs', 'good', 'with', 'dragons', 'thrown', 'into', 'the', 'mix', 'its', 'as', 'if', 'they', 'tried', 'too', 'hard', 'to', 'create', 'the', 'asian', 'version', 'of', 'black', 'pantherits', 'a', 'shame', 'because', 'the', 'directing', 'and', 'cinematography', 'were', 'spot', 'on', 'and', 'great', 'svfx', 'although', 'a', 'little', 'overboard', 'with', 'the', 'cgie', 'dragons', 'the', 'martial', 'arts', 'choreography', 'was', 'outstanding', 'although', 'again', 'overboard', 'after', 'the', 'awesome', 'bus', 'scene', 'and', 'the', 'casting', 'and', 'performances', 'were', 'excellent', 'especially', 'leung', 'who', 'pretty', 'much', 'carried', 'the', 'film', 'on', 'his', 'shoulders', 'its', 'a', '710', 'from', 'me']
# ['everything', 'comes', 'in', 'it', 'beautiful', 'science', 'fiction', 'and', 'beautiful', 'mythical', 'creatures', 'sometimes', 'you', 'have', 'creatures', 'that', 'dont', 'seem', 'real', 'but', 'these', 'just', 'seemed', 'real', 'well', 'done', 'there', 'was', 'a', 'bit', 'of', 'avatar', 'feeling', 'in', 'it', 'fighting', 'for', 'the', 'safekeeping', 'of', 'peace', 'really', 'beautiful', 'and', 'selfacceptance', 'was', 'also', 'nicely', 'incorporated']
# ['ill', 'be', 'honest', 'marvel', 'movies', 'are', 'not', 'in', 'my', 'top', '20', 'or', 'even', '50', 'but', 'within', 'the', 'marvel', 'universe', 'would', 'say', 'that', 'shangchis', 'in', 'my', 'top', '5', 'know', 'its', 'blasphemy', 'and', 'all', 'that', 'but', 'think', 'about', 'it', 'is', 'it', 'better', 'than', 'iron', 'man', 'would', 'admit', 'yes', 'its', 'origin', 'story', 'is', 'arguably', 'better', 'and', 'its', 'characters', 'are', 'a', 'lot', 'deeper', 'the', 'mandarin', 'is', 'a', 'conflicted', 'man', 'with', 'evil', 'but', 'good', 'as', 'well', 'like', 'real', 'life', 'is', 'this', 'movie', 'better', 'than', 'the', 'avengers', 'or', 'ragnarok', 'or', 'infinity', 'wars', 'hard', 'to', 'say', 'which', 'means', 'its', 'right', 'up', 'there', 'with', 'the', 'best', 'of', 'marvel', 'in', 'my', 'opinionplus', 'im', 'a', 'sucker', 'for', 'chinese', 'movies', 'with', 'the', 'chinese', 'language', 'being', 'spoken', '1', 'of', 'my', 'favourite', 'of', 'all', 'times', 'if', 'not', 'my', 'absolute', 'favourite', 'is', 'of', 'course', 'hero', 'the', 'chinese', 'language', 'and', 'the', 'artistry', 'of', 'its', 'culture', 'are', 'magnificentall', 'in', 'all', 'well', 'done', 'marvel', 'director', 'destin', 'and', 'all', 'those', 'who', 'worked', 'to', 'make', 'this', 'movie', 'a', 'reality', 'this', 'is', 'not', 'just', 'your', 'average', 'summer', 'action', 'movie', 'its', 'close', 'to', 'being', 'a', 'masterpiece', 'and', 'the', 'humour', 'is', 'pretty', 'swell', 'toocheers']
# ['shangchis', 'a', 'boring', 'film', 'the', 'characters', 'were', 'okay', 'but', 'the', 'story', 'was', 'choppy', 'and', 'confusing', 'the', 'song', 'choices', 'were', 'odd', 'plus', 'this', 'movie', 'was', 'way', 'too', 'long', 'and', 'the', 'scene', 'at', 'the', 'end', 'had', 'me', 'practically', 'falling', 'asleep']
# ['watched', 'the', 'imax', 'version', 'best', 'solo', 'since', 'iron', 'man', '2008', 'had', 'no', 'expectations', 'of', 'this', 'before', 'but', 'the', 'movie', 'is', 'much', 'more', 'lively', 'enjoyed', 'every', 'moment', 'and', 'also', 'very', 'engaging', 'from', 'start', 'to', 'finish', 'a', 'kinda', 'cuteaction', 'movie', 'with', 'some', 'fun', 'stuffthis', 'is', 'the', 'first', 'movie', 'that', 'focuses', 'more', 'on', 'martial', 'arts', 'than', 'marvels', 'superpower', 'thing', 'love', 'to', 'see', 'a', 'mix', 'of', 'marvels', 'masterlevelcgwith', 'martial', 'art', 'kungfu', 'with', 'this', 'kind', 'of', 'visual', 'effect', 'marvel', 'nailed', 'it', 'againive', 'always', 'loved', 'marvels', 'casting', 'katy', 'is', 'too', 'perfect', 'for', 'her', 'role', 'loved', 'her', 'chemistry', 'with', 'shaun', 'also', 'laughed', 'out', 'loud', 'at', 'her', 'childish', 'stuffsjust', 'one', 'thing', 'not', 'a', 'big', 'deal', 'the', 'action', 'scene', 'of', 'dragon', 'riding', 'doesnt', 'fit', 'into', 'the', 'usual', 'marvel', 'movie', 'but', 'as', 'chinese', 'flavor', 'it', 'is', 'ok', 'except', 'for', 'this', 'the', 'cinematography', 'and', 'vfx', 'are', 'a', 'lot', 'mesmerizing']
# ['lets', 'agree', 'that', 'it', 'is', 'a', 'bad', 'movie', 'from', 'multiple', 'points', 'of', 'view', 'it', 'depends', 'a', 'lot', 'on', 'the', 'visual', 'effects', 'its', 'main', 'characters', 'can', 'be', 'funny', 'but', 'not', 'nice', 'the', 'story', 'does', 'not', 'generate', 'much', 'interest', 'and', 'we', 'have', 'seen', 'the', 'fights', 'many', 'times', 'and', 'in', 'a', 'better', 'way', 'in', 'almost', 'any', 'film', 'produced', 'in', 'hong', 'kong', 'indonesia', 'or', 'thailand', 'of', 'the', 'last', 'twenty', 'years', 'the', 'only', 'thing', 'that', 'saves', 'this', 'film', 'is', 'the', 'karaoke', 'scene', 'that', 'is', 'unexpectedly', 'welcome', 'the', 'rest', 'is', 'routine', 'mediocre', 'tiring', 'and', 'bland']
# ['as', 'far', 'as', 'visuals', 'go', 'this', 'movie', 'is', 'amazing', 'like', 'just', 'about', 'as', 'impressive', 'as', 'dune', 'its', 'filled', 'to', 'the', 'brim', 'with', 'eyecandythe', 'plotstory', 'however', 'is', 'mediocre', 'and', 'filled', 'with', 'plot', 'holes', 'the', 'characters', 'actions', 'are', 'often', 'unrealistic', 'and', 'they', 'will', 'often', 'just', 'stare', 'in', 'awe', 'at', 'their', 'friends', 'being', 'killed', 'instead', 'of', 'doing', 'the', 'realistic', 'thing', 'and', 'immediately', 'defending', 'their', 'friends', 'its', 'something', 'that', 'happens', 'like', '5', 'times', 'and', 'honestly', 'spoils', 'the', 'movie', 'for', 'me', 'if', 'characters', 'in', 'a', 'movie', 'dont', 'act', 'or', 'react', 'realistically', 'and', 'stare', 'at', 'something', 'like', 'a', 'braindead', 'zombie', 'like', 'their', 'friends', 'getting', 'killed', 'right', 'in', 'front', 'of', 'them', 'whilst', 'they', 'are', 'holding', 'a', 'gun', 'in', 'their', 'freeking', 'hands', 'then', 'its', 'just', 'really', 'terrible', 'scriptplot', 'writingoverall', 'the', 'movie', 'isnt', 'as', 'bad', 'as', 'antman', '2', 'but', 'its', 'not', 'far', 'behind', 'also', 'awkwafinas', 'acting', 'style', 'was', 'already', 'old', 'by', 'the', '2nd', 'movie', 'she', 'did', 'all', 'of', 'her', 'characters', 'in', 'movies', 'are', 'the', 'same', 'person', 'and', 'like', 'said', 'it', 'got', 'boring', 'after', 'the', '2nd', 'movie', 'roll', 'my', 'eyes', 'at', 'everything', 'awkwafinas', 'character', 'does', 'in', 'the', 'movieits', 'a', '510', 'movie', 'not', 'really', 'worth', 'a', 'watch', 'unless', 'youre', 'a', 'real', 'diehard', 'marvel', 'fan']
# ['rated', '810', 'language', 'english', 'source', 'hotstar', 'recommendedthe', 'story', 'and', 'making', 'is', 'worth', 'to', 'watch', 'in', 'big', 'screen', 'with', 'good', 'sound', 'system', 'the', 'first', 'half', 'is', 'filled', 'with', 'great', 'actions', 'and', 'funny', 'moments', 'and', 'it', 'get', 'into', 'serious', 'mode', 'in', 'the', 'second', 'halfthe', 'second', 'half', 'is', 'more', 'traditional', 'and', 'sentimentalthe', 'decent', 'story', 'and', 'colourful', 'visual', 'makes', 'this', 'so', 'grand', 'good', 'movie', 'to', 'watch', 'with', 'family']
# ['martial', 'arts', 'meets', 'the', 'mcu', 'in', 'shangchand', 'the', 'legend', 'of', 'the', 'ten', 'rings', 'more', 'crouching', 'tiger', 'than', 'jackie', 'chan', 'the', 'plot', 'for', 'the', 'film', 'is', 'kinda', 'humdrum', 'the', 'sort', 'of', 'mystical', 'eastern', 'fantasy', 'cobblers', 'that', 'practically', 'writes', 'itselfshangchis', 'the', 'son', 'of', 'immortal', 'powerhungry', 'warlord', 'xu', 'wenwu', 'tony', 'chiuwaleung', 'and', 'lfala', 'chen', 'a', 'warrior', 'woman', 'from', 'the', 'hidden', 'village', 'of', 'ta', 'lo', 'after', 'falling', 'in', 'love', 'with', 'land', 'becoming', 'a', 'father', 'wenwu', 'gives', 'up', 'his', 'wicked', 'ways', 'and', 'packs', 'away', 'the', 'ten', 'legendary', 'rings', 'that', 'gave', 'him', 'much', 'of', 'his', 'power', 'however', 'after', 'his', 'wife', 'is', 'killed', 'by', 'his', 'old', 'enemies', 'wenwu', 'once', 'again', 'wears', 'the', 'rings', 'and', 'trains', 'his', 'son', 'to', 'become', 'an', 'assassin', 'ashamed', 'of', 'what', 'he', 'has', 'become', 'shangchgoes', 'into', 'hiding', 'in', 'america', 'and', 'becomes', 'shaun', 'simu', 'liu', 'but', 'his', 'past', 'eventually', 'catches', 'up', 'with', 'him', 'when', 'his', 'father', 'sends', 'his', 'army', 'the', 'ten', 'rings', 'to', 'steal', 'the', 'pendants', 'given', 'to', 'him', 'and', 'his', 'sister', 'xialing', 'menger', 'zhang', 'by', 'their', 'mother', 'wenwu', 'requires', 'both', 'pendants', 'to', 'reveal', 'the', 'way', 'to', 'ta', 'lo', 'where', 'he', 'believes', 'that', 'his', 'wife', 'is', 'being', 'held', 'captive', 'by', 'her', 'peoplethis', 'marvel', 'movie', 'is', 'at', 'its', 'most', 'fun', 'before', 'the', 'plot', 'starts', 'to', 'get', 'in', 'the', 'way', 'and', 'the', 'cgbecomes', 'too', 'overbearing', 'and', 'intrusive', 'the', 'early', 'fight', 'scenes', 'a', 'battle', 'on', 'a', 'runaway', 'bus', 'against', 'a', 'henchman', 'known', 'as', 'razor', 'fist', 'and', 'a', 'fight', 'on', 'some', 'highrise', 'bamboo', 'scaffolding', 'deliver', 'lots', 'of', 'impressively', 'choreographed', 'action', 'that', 'will', 'please', 'both', 'martial', 'arts', 'fans', 'and', 'superhero', 'addicts', 'awkwafina', 'as', 'shangchis', 'loyal', 'friend', 'katy', 'provides', 'some', 'comic', 'relief', 'but', 'also', 'gets', 'stuck', 'in', 'with', 'the', 'actionunfortunately', 'the', 'film', 'quickly', 'goes', 'downhill', 'after', 'the', 'good', 'guys', 'make', 'their', 'way', 'to', 'ta', 'lo', 'with', 'a', 'little', 'help', 'from', 'tony', 'slattery', 'see', 'iron', 'man', '3', 'and', 'a', 'furry', 'winged', 'creature', 'with', 'no', 'face', 'the', 'inevitable', 'battle', 'between', 'the', 'villagers', 'and', 'wenwus', 'army', 'is', 'typical', 'overblown', 'marvel', 'mayhem', 'but', 'the', 'massive', 'cgtsunamarrives', 'when', 'wenwu', 'opens', 'the', 'interdimensional', 'gate', 'that', 'he', 'thinks', 'is', 'holding', 'lprisoner', 'instead', 'of', 'releasing', 'his', 'wife', 'he', 'frees', 'a', 'swarm', 'of', 'flying', 'tentacled', 'soulsuckers', 'and', 'their', 'big', 'bad', 'boss', 'the', 'dweller', 'fortunately', 'for', 'the', 'ta', 'lo', 'people', 'they', 'have', 'a', 'massive', 'magical', 'dragon', 'on', 'their', 'side', 'which', 'wakes', 'up', 'and', 'adds', 'to', 'the', 'digital', 'whizzbangeryas', 'technically', 'impressive', 'as', 'the', 'special', 'effects', 'are', 'found', 'the', 'second', 'half', 'of', 'the', 'film', 'visually', 'overwhelming', 'yet', 'remarkably', 'uninvolving', 'a', 'whirlwind', 'of', 'pixels', 'and', 'noisy', 'action', 'without', 'much', 'substance510', 'it', 'was', 'nice', 'to', 'see', 'hkchinese', 'stars', 'michelle', 'yeoh', 'tony', 'leung', 'and', 'yuen', 'wah', 'together', 'in', 'a', 'marvel', 'movie', 'just', 'wish', 'it', 'had', 'been', 'a', 'better', 'one']
# ['shangchand', 'the', 'legend', 'of', 'the', 'ten', 'rings', 'takes', 'place', 'some', 'time', 'after', 'avengers', 'endgame', 'is', 'the', 'beginning', 'of', 'phase', 'four', 'of', 'the', 'marvel', 'cinematic', 'universeshangchis', 'an', 'alright', 'movie', 'it', 'has', 'some', 'great', 'fight', 'scenes', 'with', 'some', 'incredible', 'fight', 'choreography', 'and', 'epic', 'largescale', 'battles', 'it', 'is', 'also', 'has', 'some', 'good', 'comedic', 'scenes', 'that', 'made', 'me', 'laugh', 'a', 'couple', 'of', 'times', 'where', 'shangchsuffers', 'is', 'when', 'it', 'comes', 'to', 'the', 'plot', 'didnt', 'find', 'the', 'story', 'very', 'compelling', 'and', 'didnt', 'get', 'that', 'attached', 'to', 'the', 'characters', 'its', 'a', 'story', 'that', 'feel', 'has', 'been', 'done', 'many', 'times', 'beforeshangchwasnt', 'for', 'me', 'but', 'its', 'comedy', 'and', 'fight', 'scenes', 'make', 'up', 'for', 'some', 'of', 'its', 'flaws', 'if', 'you', 'are', 'familiar', 'with', 'the', 'marvel', 'franchise', 'assume', 'you', 'somewhat', 'know', 'what', 'to', 'expect', 'and', 'for', 'you', 'can', 'recommend', 'it', 'although', 'the', 'movie', 'isnt', 'that', 'great', 'still', 'think', 'its', 'good', 'enough', 'to', 'the', 'point', 'of', 'where', 'its', 'worth', 'watching', 'just', 'to', 'keep', 'up', 'with', 'the', 'larger', 'plot', 'of', 'the', 'mcu', 'for', 'those', 'not', 'invested', 'in', 'the', 'mcu', 'dont', 'believe', 'that', 'this', 'movie', 'is', 'the', 'one', 'you', 'should', 'start', 'with']
# ['the', 'best', 'marvel', 'movie', 'after', 'endgame', 'the', 'story', 'is', 'a', 'bit', 'cliché', 'but', 'the', 'rest', 'is', 'absolutely', 'amazing', 'the', 'fight', 'scenes', 'are', 'the', 'best', 'in', 'the', 'mcu', 'in', 'my', 'opinion', 'simu', 'liu', 'as', 'shangchis', 'perfectly', 'chosen', 'and', 'all', 'the', 'other', 'characters', 'are', 'nice', 'and', 'the', 'all', 'the', 'actors', 'do', 'a', 'good', 'job', 'act', '3', 'is', 'on', 'another', 'level', 'that', 'we', 'havent', 'seen', 'before', 'in', 'mcu', 'and', 'the', 'visual', 'effects', 'are', 'spectacular', 'by', 'far', 'one', 'of', 'the', 'best', 'origin', 'stories', 'from', 'marvel']
# ['it', 'had', 'potential', 'but', 'marvel', 'has', 'this', 'tendency', 'of', 'degrading', 'everything', 'into', 'mindless', 'comedythings', 'just', 'happen', 'to', 'an', 'extent', 'where', 'awkwafina', 'is', 'now', 'an', 'avenger', 'im', 'getting', 'too', 'old', 'for', 'this', 'st']
# ['really', 'entertaining', 'movie', 'actors', 'were', 'great', 'simu', 'liu', 'brought', 'it', 'big', 'time', 'he', 'is', 'excellent', 'as', 'the', 'main', 'character', 'awkwafina', 'is', 'hilarious', 'and', 'wish', 'she', 'had', 'more', 'screen', 'time', 'as', 'far', 'as', 'marvel', 'movies', 'goes', 'its', 'not', 'the', 'best', 'one', 'but', 'still', 'very', 'good']
# ['this', 'is', 'the', 'story', 'of', 'ten', 'rings', 'weapons', 'used', 'for', 'thousands', 'of', 'years', 'to', 'take', 'power', 'and', 'control', 'shang', 'ch', 'simu', 'liu', 'as', 'chang', 'x', 'accidentally', 'gets', 'pulled', 'into', 'the', 'history', 'and', 'cant', 'turn', 'back', 'costars', 'awkwafina', 'tony', 'leung', 'both', 'winners', 'of', 'tons', 'of', 'film', 'festival', 'awards', 'also', 'ben', 'kingsley', 'oscar', 'for', 'gandhalthough', 'he', 'looks', 'so', 'different', 'you', 'may', 'not', 'recognize', 'kingsley', 'in', 'his', 'role', 'its', 'a', 'marvel', 'story', 'from', 'disney', 'so', 'theres', 'a', 'good', 'mix', 'of', 'adventure', 'violence', 'animation', 'levitation', 'and', 'some', 'jokes', 'sprinkled', 'here', 'and', 'there', 'the', 'bad', 'guys', 'are', 'collecting', 'the', 'pendants', 'with', 'the', 'power', 'and', 'can', 'not', 'be', 'allowed', 'to', 'gether', 'them', 'all', 'surprisingly', 'a', 'couple', 'swears', 'giving', 'it', 'the', 'pg13', 'rating', 'they', 'meet', 'good', 'people', 'that', 'want', 'to', 'help', 'them', 'on', 'their', 'journey', 'and', 'evil', 'people', 'that', 'want', 'to', 'destroy', 'them', 'some', 'fun', 'special', 'effects', 'directed', 'by', 'destin', 'cretton', 'chang', 'xcharacter', 'created', 'by', 'steve', 'englehart', 'jim', 'starlin', 'its', 'quite', 'good']
# ['really', 'liked', 'that', 'the', 'actors', 'spoke', 'their', 'native', 'language', 'mandarin', 'because', 'it', 'wouldve', 'felt', 'too', 'americanized', 'otherwise', 'but', 'there', 'was', 'something', 'unfinished', 'about', 'this', 'movie', 'and', 'im', 'not', 'sure', 'what', 'it', 'is', 'the', 'pacing', 'was', 'alright', 'a', 'little', 'too', 'slow', 'or', 'fast', 'at', 'times', 'and', 'as', 'far', 'as', 'storylines', 'go', 'it', 'was', 'not', 'as', 'exciting', 'as', 'thought', 'it', 'would', 'be', 'the', 'fight', 'scenes', 'were', 'great', 'though', 'especially', 'the', 'final', 'grand', 'battle', 'scene']
# ['this', 'is', 'the', 'worst', 'marvel', 'movie', 'have', 'seen', 'to', 'dateafter', 'seeing', 'the', 'movie', 'was', 'honestly', 'surprised', 'by', 'all', 'the', 'high', 'ratings', 'did', 'we', 'watch', 'the', 'same', 'thing', 'the', 'movie', 'is', 'without', 'a', 'soul', 'characters', 'arent', 'build', 'up', 'enough', 'even', 'with', 'a', '2', 'hour', 'run', 'time', 'the', 'movie', 'literally', 'got', 'nothing', 'to', 'do', 'with', 'the', 'ten', 'rings', 'movie', 'became', 'godzilla', 'vs', 'king', 'kong', 'at', 'the', 'end', 'waste', 'of', '2', 'hours', 'honestly', 'clueless', 'why', 'people', 'high', 'praised', 'for', 'this', 'movie', 'what', 'a', 'waste', 'of', 'opportunity', 'to', 'create', 'a', 'wonderful', 'and', 'authentic', 'world', 'for', 'asian', 'marvel', 'universe']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [['got',
#   'admit',
#   'wasnt',
#   'particularli',
#   'blown',
#   'away',
#   'anyth',
#   'movi',
#   'might',
#   'even',
#   'say',
#   'bore',
#   'itdont',
#   'get',
#   'wrong',
#   'spectacl',
#   'action',
#   'great',
#   'locat',
#   'nice',
#   'costum',
#   'design',
#   'sound',
#   'design',
#   'etc',
#   'overal',
#   'soft',
#   'releas',
#   'worth',
#   'see',
#   'theater',
#   'special',
#   'followup',
#   'endgam',
#   'wasth',
#   'biggest',
#   'problem',
#   'underwritten',
#   'lead',
#   'muddl',
#   'person',
#   'reason',
#   'cover',
#   'stori',
#   'devoid',
#   'charm',
#   'person',
#   'good',
#   'dialogueth',
#   'next',
#   'issu',
#   'humor',
#   'didnt',
#   'land',
#   'support',
#   'lead',
#   'awkwafina',
#   'isnt',
#   'normal',
#   'loud',
#   'self',
#   'that',
#   'suppos',
#   'funni',
#   'everi',
#   'time',
#   'open',
#   'mouth',
#   'role',
#   'support',
#   'littl',
#   'dramat',
#   'question',
#   'even',
#   'doesnt',
#   'ultim',
#   'matter',
#   'anoth',
#   'forgett',
#   'charact',
#   'given',
#   'import',
#   'role',
#   'deservesfin',
#   'third',
#   'act',
#   'weak',
#   'there',
#   'balanc',
#   'problem',
#   'stake',
#   'cant',
#   'feel',
#   'tension',
#   'weight',
#   'action',
#   'there',
#   'lot',
#   'superfici',
#   'cant',
#   'canin',
#   'end',
#   'feel',
#   'like',
#   'safe',
#   'plot',
#   'written',
#   'way',
#   'appeal',
#   'china',
#   'consid',
#   'mandarin',
#   'portray',
#   'end',
#   'appeal',
#   'one',
#   'specif',
#   'certainli',
#   'doesnt',
#   'feel',
#   'like',
#   'marvel',
#   'movi',
#   'bound',
#   'happen',
#   'introduc',
#   'differ',
#   'aspect',
#   'narr',
#   'also',
#   'doesnt',
#   'feel',
#   'like',
#   'comic',
#   'book',
#   'gener'],
#  ['charact',
#   'bit',
#   'incoher',
#   'straight',
#   'contradict',
#   'character',
#   'time',
#   'plot',
#   'need',
#   'bunch',
#   'unneed',
#   'deuxex',
#   'machina',
#   'conveni',
#   'writer',
#   'trap',
#   'corner',
#   'reason',
#   'that',
#   'happen',
#   'get',
#   '2021',
#   'mortal',
#   'kombat',
#   'ww84',
#   'expend',
#   'writersalso',
#   'awkwafina',
#   'destroy',
#   'everi',
#   'type',
#   'scene',
#   'dramat',
#   'epic',
#   'also',
#   'comed',
#   'one',
#   'one',
#   'worst',
#   'act',
#   'ive',
#   'ever',
#   'seen',
#   'type',
#   'joke',
#   'awkward',
#   'nonsens',
#   'start',
#   'finish',
#   'role',
#   'ridicul',
#   'larg',
#   'dumb',
#   'comic',
#   'reliefbut',
#   'liu',
#   'actual',
#   'pretti',
#   'good',
#   'lead',
#   'charact',
#   'potenti',
#   'great',
#   'shangchworld',
#   'beauti',
#   'everyth',
#   'super',
#   'fun',
#   'watch',
#   'futurewithout',
#   'awkwafin',
#   'better',
#   'writer'],
#  ['destin',
#   'daniel',
#   'cretton',
#   'shangchand',
#   'legend',
#   'ten',
#   'ring',
#   'mark',
#   'bland',
#   'start',
#   'new',
#   'phase',
#   'marvel',
#   'cinemat',
#   'univers',
#   'spectacl',
#   'regard',
#   'action',
#   'sequenc',
#   'fight',
#   'choreographi',
#   'film',
#   'miss',
#   'solid',
#   'storylin',
#   'origin',
#   'stori',
#   'titular',
#   'charact',
#   'lack',
#   'person',
#   'go',
#   'heroic',
#   'transform',
#   'stori',
#   'arc',
#   'simu',
#   'liu',
#   'strong',
#   'presenc',
#   'shangchyet',
#   'overshadow',
#   'mani',
#   'experienc',
#   'costar'],
#  ['stori',
#   'riddl',
#   'hole',
#   'plot',
#   'issu',
#   'sinc',
#   'awkwafina',
#   'pedestrian',
#   'charact',
#   'sudden',
#   'get',
#   'invit',
#   'becom',
#   'part',
#   'mcu',
#   'team',
#   'what',
#   'super',
#   'power',
#   'stupid',
#   'dont',
#   'get',
#   'wrong',
#   'love',
#   'charact',
#   'lazili',
#   'written',
#   'there',
#   'whole',
#   'daddi',
#   'issu',
#   'dynam',
#   'shang',
#   'etc',
#   'ridicul',
#   'dragon',
#   'fight',
#   'one',
#   'score',
#   'power',
#   'crystal',
#   'becom',
#   'stronger',
#   'infantil',
#   'lazi',
#   'write',
#   'zero',
#   'shock',
#   'valu',
#   'anyth',
#   'spectacular',
#   'entir',
#   'runtim',
#   'tediou',
#   'long',
#   'middl',
#   'act',
#   'bumbl',
#   'third',
#   'act',
#   'joke',
#   'clich',
#   'funni',
#   'funniest',
#   'part',
#   'ben',
#   'kingsley',
#   'charact',
#   'reason',
#   'end',
#   'go',
#   'karaok',
#   'time',
#   'actual',
#   'crack',
#   'chuckl',
#   'youd',
#   'think',
#   'three',
#   'writer',
#   'wed',
#   'someth',
#   'cohes',
#   'coher',
#   'instead',
#   'marvel',
#   'superhero',
#   'stori',
#   'got',
#   'disney',
#   'evil',
#   'v',
#   'good',
#   'dragon',
#   'thrown',
#   'mix',
#   'tri',
#   'hard',
#   'creat',
#   'asian',
#   'version',
#   'black',
#   'pantherit',
#   'shame',
#   'direct',
#   'cinematographi',
#   'spot',
#   'great',
#   'svfx',
#   'although',
#   'littl',
#   'overboard',
#   'cgie',
#   'dragon',
#   'martial',
#   'art',
#   'choreographi',
#   'outstand',
#   'although',
#   'overboard',
#   'awesom',
#   'bu',
#   'scene',
#   'cast',
#   'perform',
#   'excel',
#   'especi',
#   'leung',
#   'pretti',
#   'much',
#   'carri',
#   'film',
#   'shoulder',
#   '710'],
#  ['everyth',
#   'come',
#   'beauti',
#   'scienc',
#   'fiction',
#   'beauti',
#   'mythic',
#   'creatur',
#   'sometim',
#   'creatur',
#   'dont',
#   'seem',
#   'real',
#   'seem',
#   'real',
#   'well',
#   'done',
#   'bit',
#   'avatar',
#   'feel',
#   'fight',
#   'safekeep',
#   'peac',
#   'realli',
#   'beauti',
#   'selfaccept',
#   'also',
#   'nice',
#   'incorpor'],
#  ['ill',
#   'honest',
#   'marvel',
#   'movi',
#   'top',
#   '20',
#   'even',
#   '50',
#   'within',
#   'marvel',
#   'univers',
#   'would',
#   'say',
#   'shangchi',
#   'top',
#   '5',
#   'know',
#   'blasphemi',
#   'think',
#   'better',
#   'iron',
#   'man',
#   'would',
#   'admit',
#   'ye',
#   'origin',
#   'stori',
#   'arguabl',
#   'better',
#   'charact',
#   'lot',
#   'deeper',
#   'mandarin',
#   'conflict',
#   'man',
#   'evil',
#   'good',
#   'well',
#   'like',
#   'real',
#   'life',
#   'movi',
#   'better',
#   'aveng',
#   'ragnarok',
#   'infin',
#   'war',
#   'hard',
#   'say',
#   'mean',
#   'right',
#   'best',
#   'marvel',
#   'opinionplu',
#   'im',
#   'sucker',
#   'chines',
#   'movi',
#   'chines',
#   'languag',
#   'spoken',
#   '1',
#   'favourit',
#   'time',
#   'absolut',
#   'favourit',
#   'cours',
#   'hero',
#   'chines',
#   'languag',
#   'artistri',
#   'cultur',
#   'magnificental',
#   'well',
#   'done',
#   'marvel',
#   'director',
#   'destin',
#   'work',
#   'make',
#   'movi',
#   'realiti',
#   'averag',
#   'summer',
#   'action',
#   'movi',
#   'close',
#   'masterpiec',
#   'humour',
#   'pretti',
#   'swell',
#   'toocheer'],
#  ['shangchi',
#   'bore',
#   'film',
#   'charact',
#   'okay',
#   'stori',
#   'choppi',
#   'confus',
#   'song',
#   'choic',
#   'odd',
#   'plu',
#   'movi',
#   'way',
#   'long',
#   'scene',
#   'end',
#   'practic',
#   'fall',
#   'asleep'],
#  ['watch',
#   'imax',
#   'version',
#   'best',
#   'solo',
#   'sinc',
#   'iron',
#   'man',
#   '2008',
#   'expect',
#   'movi',
#   'much',
#   'live',
#   'enjoy',
#   'everi',
#   'moment',
#   'also',
#   'engag',
#   'start',
#   'finish',
#   'kinda',
#   'cuteact',
#   'movi',
#   'fun',
#   'stuffthi',
#   'first',
#   'movi',
#   'focu',
#   'martial',
#   'art',
#   'marvel',
#   'superpow',
#   'thing',
#   'love',
#   'see',
#   'mix',
#   'marvel',
#   'masterlevelcgwith',
#   'martial',
#   'art',
#   'kungfu',
#   'kind',
#   'visual',
#   'effect',
#   'marvel',
#   'nail',
#   'again',
#   'alway',
#   'love',
#   'marvel',
#   'cast',
#   'kati',
#   'perfect',
#   'role',
#   'love',
#   'chemistri',
#   'shaun',
#   'also',
#   'laugh',
#   'loud',
#   'childish',
#   'stuffsjust',
#   'one',
#   'thing',
#   'big',
#   'deal',
#   'action',
#   'scene',
#   'dragon',
#   'ride',
#   'doesnt',
#   'fit',
#   'usual',
#   'marvel',
#   'movi',
#   'chines',
#   'flavor',
#   'ok',
#   'except',
#   'cinematographi',
#   'vfx',
#   'lot',
#   'mesmer'],
#  ['let',
#   'agre',
#   'bad',
#   'movi',
#   'multipl',
#   'point',
#   'view',
#   'depend',
#   'lot',
#   'visual',
#   'effect',
#   'main',
#   'charact',
#   'funni',
#   'nice',
#   'stori',
#   'gener',
#   'much',
#   'interest',
#   'seen',
#   'fight',
#   'mani',
#   'time',
#   'better',
#   'way',
#   'almost',
#   'film',
#   'produc',
#   'hong',
#   'kong',
#   'indonesia',
#   'thailand',
#   'last',
#   'twenti',
#   'year',
#   'thing',
#   'save',
#   'film',
#   'karaok',
#   'scene',
#   'unexpectedli',
#   'welcom',
#   'rest',
#   'routin',
#   'mediocr',
#   'tire',
#   'bland'],
#  ['far',
#   'visual',
#   'go',
#   'movi',
#   'amaz',
#   'like',
#   'impress',
#   'dune',
#   'fill',
#   'brim',
#   'eyecandyth',
#   'plotstori',
#   'howev',
#   'mediocr',
#   'fill',
#   'plot',
#   'hole',
#   'charact',
#   'action',
#   'often',
#   'unrealist',
#   'often',
#   'stare',
#   'awe',
#   'friend',
#   'kill',
#   'instead',
#   'realist',
#   'thing',
#   'immedi',
#   'defend',
#   'friend',
#   'someth',
#   'happen',
#   'like',
#   '5',
#   'time',
#   'honestli',
#   'spoil',
#   'movi',
#   'charact',
#   'movi',
#   'dont',
#   'act',
#   'react',
#   'realist',
#   'stare',
#   'someth',
#   'like',
#   'braindead',
#   'zombi',
#   'like',
#   'friend',
#   'get',
#   'kill',
#   'right',
#   'front',
#   'whilst',
#   'hold',
#   'gun',
#   'freek',
#   'hand',
#   'realli',
#   'terribl',
#   'scriptplot',
#   'writingoveral',
#   'movi',
#   'isnt',
#   'bad',
#   'antman',
#   '2',
#   'far',
#   'behind',
#   'also',
#   'awkwafina',
#   'act',
#   'style',
#   'alreadi',
#   'old',
#   '2nd',
#   'movi',
#   'charact',
#   'movi',
#   'person',
#   'like',
#   'said',
#   'got',
#   'bore',
#   '2nd',
#   'movi',
#   'roll',
#   'eye',
#   'everyth',
#   'awkwafina',
#   'charact',
#   'movieit',
#   '510',
#   'movi',
#   'realli',
#   'worth',
#   'watch',
#   'unless',
#   'your',
#   'real',
#   'diehard',
#   'marvel',
#   'fan'],
#  ['rate',
#   '810',
#   'languag',
#   'english',
#   'sourc',
#   'hotstar',
#   'recommendedth',
#   'stori',
#   'make',
#   'worth',
#   'watch',
#   'big',
#   'screen',
#   'good',
#   'sound',
#   'system',
#   'first',
#   'half',
#   'fill',
#   'great',
#   'action',
#   'funni',
#   'moment',
#   'get',
#   'seriou',
#   'mode',
#   'second',
#   'halfth',
#   'second',
#   'half',
#   'tradit',
#   'sentimentalth',
#   'decent',
#   'stori',
#   'colour',
#   'visual',
#   'make',
#   'grand',
#   'good',
#   'movi',
#   'watch',
#   'famili'],
#  ['martial',
#   'art',
#   'meet',
#   'mcu',
#   'shangchand',
#   'legend',
#   'ten',
#   'ring',
#   'crouch',
#   'tiger',
#   'jacki',
#   'chan',
#   'plot',
#   'film',
#   'kinda',
#   'humdrum',
#   'sort',
#   'mystic',
#   'eastern',
#   'fantasi',
#   'cobbler',
#   'practic',
#   'write',
#   'itselfshangchi',
#   'son',
#   'immort',
#   'powerhungri',
#   'warlord',
#   'xu',
#   'wenwu',
#   'toni',
#   'chiuwaleung',
#   'lfala',
#   'chen',
#   'warrior',
#   'woman',
#   'hidden',
#   'villag',
#   'ta',
#   'lo',
#   'fall',
#   'love',
#   'land',
#   'becom',
#   'father',
#   'wenwu',
#   'give',
#   'wick',
#   'way',
#   'pack',
#   'away',
#   'ten',
#   'legendari',
#   'ring',
#   'gave',
#   'much',
#   'power',
#   'howev',
#   'wife',
#   'kill',
#   'old',
#   'enemi',
#   'wenwu',
#   'wear',
#   'ring',
#   'train',
#   'son',
#   'becom',
#   'assassin',
#   'asham',
#   'becom',
#   'shangchgo',
#   'hide',
#   'america',
#   'becom',
#   'shaun',
#   'simu',
#   'liu',
#   'past',
#   'eventu',
#   'catch',
#   'father',
#   'send',
#   'armi',
#   'ten',
#   'ring',
#   'steal',
#   'pendant',
#   'given',
#   'sister',
#   'xial',
#   'menger',
#   'zhang',
#   'mother',
#   'wenwu',
#   'requir',
#   'pendant',
#   'reveal',
#   'way',
#   'ta',
#   'lo',
#   'belief',
#   'wife',
#   'held',
#   'captiv',
#   'peoplethi',
#   'marvel',
#   'movi',
#   'fun',
#   'plot',
#   'start',
#   'get',
#   'way',
#   'cgbecom',
#   'overbear',
#   'intrus',
#   'earli',
#   'fight',
#   'scene',
#   'battl',
#   'runaway',
#   'bu',
#   'henchman',
#   'known',
#   'razor',
#   'fist',
#   'fight',
#   'highris',
#   'bamboo',
#   'scaffold',
#   'deliv',
#   'lot',
#   'impress',
#   'choreograph',
#   'action',
#   'pleas',
#   'martial',
#   'art',
#   'fan',
#   'superhero',
#   'addict',
#   'awkwafina',
#   'shangchi',
#   'loyal',
#   'friend',
#   'kati',
#   'provid',
#   'comic',
#   'relief',
#   'also',
#   'get',
#   'stuck',
#   'actionunfortun',
#   'film',
#   'quickli',
#   'go',
#   'downhil',
#   'good',
#   'guy',
#   'make',
#   'way',
#   'ta',
#   'lo',
#   'littl',
#   'help',
#   'toni',
#   'slatteri',
#   'see',
#   'iron',
#   'man',
#   '3',
#   'furri',
#   'wing',
#   'creatur',
#   'face',
#   'inevit',
#   'battl',
#   'villag',
#   'wenwu',
#   'armi',
#   'typic',
#   'overblown',
#   'marvel',
#   'mayhem',
#   'massiv',
#   'cgtsunamarr',
#   'wenwu',
#   'open',
#   'interdimension',
#   'gate',
#   'think',
#   'hold',
#   'lprison',
#   'instead',
#   'releas',
#   'wife',
#   'free',
#   'swarm',
#   'fli',
#   'tentacl',
#   'soulsuck',
#   'big',
#   'bad',
#   'bo',
#   'dweller',
#   'fortun',
#   'ta',
#   'lo',
#   'peopl',
#   'massiv',
#   'magic',
#   'dragon',
#   'side',
#   'wake',
#   'add',
#   'digit',
#   'whizzbangerya',
#   'technic',
#   'impress',
#   'special',
#   'effect',
#   'found',
#   'second',
#   'half',
#   'film',
#   'visual',
#   'overwhelm',
#   'yet',
#   'remark',
#   'uninvolv',
#   'whirlwind',
#   'pixel',
#   'noisi',
#   'action',
#   'without',
#   'much',
#   'substance510',
#   'nice',
#   'see',
#   'hkchines',
#   'star',
#   'michel',
#   'yeoh',
#   'toni',
#   'leung',
#   'yuen',
#   'wah',
#   'togeth',
#   'marvel',
#   'movi',
#   'wish',
#   'better',
#   'one'],
#  ['shangchand',
#   'legend',
#   'ten',
#   'ring',
#   'take',
#   'place',
#   'time',
#   'aveng',
#   'endgam',
#   'begin',
#   'phase',
#   'four',
#   'marvel',
#   'cinemat',
#   'universeshangchi',
#   'alright',
#   'movi',
#   'great',
#   'fight',
#   'scene',
#   'incred',
#   'fight',
#   'choreographi',
#   'epic',
#   'largescal',
#   'battl',
#   'also',
#   'good',
#   'comed',
#   'scene',
#   'made',
#   'laugh',
#   'coupl',
#   'time',
#   'shangchsuff',
#   'come',
#   'plot',
#   'didnt',
#   'find',
#   'stori',
#   'compel',
#   'didnt',
#   'get',
#   'attach',
#   'charact',
#   'stori',
#   'feel',
#   'done',
#   'mani',
#   'time',
#   'beforeshangchwasnt',
#   'comedi',
#   'fight',
#   'scene',
#   'make',
#   'flaw',
#   'familiar',
#   'marvel',
#   'franchis',
#   'assum',
#   'somewhat',
#   'know',
#   'expect',
#   'recommend',
#   'although',
#   'movi',
#   'isnt',
#   'great',
#   'still',
#   'think',
#   'good',
#   'enough',
#   'point',
#   'worth',
#   'watch',
#   'keep',
#   'larger',
#   'plot',
#   'mcu',
#   'invest',
#   'mcu',
#   'dont',
#   'believ',
#   'movi',
#   'one',
#   'start'],
#  ['best',
#   'marvel',
#   'movi',
#   'endgam',
#   'stori',
#   'bit',
#   'cliché',
#   'rest',
#   'absolut',
#   'amaz',
#   'fight',
#   'scene',
#   'best',
#   'mcu',
#   'opinion',
#   'simu',
#   'liu',
#   'shangchi',
#   'perfectli',
#   'chosen',
#   'charact',
#   'nice',
#   'actor',
#   'good',
#   'job',
#   'act',
#   '3',
#   'anoth',
#   'level',
#   'havent',
#   'seen',
#   'mcu',
#   'visual',
#   'effect',
#   'spectacular',
#   'far',
#   'one',
#   'best',
#   'origin',
#   'stori',
#   'marvel'],
#  ['potenti',
#   'marvel',
#   'tendenc',
#   'degrad',
#   'everyth',
#   'mindless',
#   'comedyth',
#   'happen',
#   'extent',
#   'awkwafina',
#   'aveng',
#   'im',
#   'get',
#   'old',
#   'st'],
#  ['realli',
#   'entertain',
#   'movi',
#   'actor',
#   'great',
#   'simu',
#   'liu',
#   'brought',
#   'big',
#   'time',
#   'excel',
#   'main',
#   'charact',
#   'awkwafina',
#   'hilari',
#   'wish',
#   'screen',
#   'time',
#   'far',
#   'marvel',
#   'movi',
#   'go',
#   'best',
#   'one',
#   'still',
#   'good'],
#  ['stori',
#   'ten',
#   'ring',
#   'weapon',
#   'use',
#   'thousand',
#   'year',
#   'take',
#   'power',
#   'control',
#   'shang',
#   'ch',
#   'simu',
#   'liu',
#   'chang',
#   'x',
#   'accident',
#   'get',
#   'pull',
#   'histori',
#   'cant',
#   'turn',
#   'back',
#   'costar',
#   'awkwafina',
#   'toni',
#   'leung',
#   'winner',
#   'ton',
#   'film',
#   'festiv',
#   'award',
#   'also',
#   'ben',
#   'kingsley',
#   'oscar',
#   'gandhalthough',
#   'look',
#   'differ',
#   'may',
#   'recogn',
#   'kingsley',
#   'role',
#   'marvel',
#   'stori',
#   'disney',
#   'there',
#   'good',
#   'mix',
#   'adventur',
#   'violenc',
#   'anim',
#   'levit',
#   'joke',
#   'sprinkl',
#   'bad',
#   'guy',
#   'collect',
#   'pendant',
#   'power',
#   'allow',
#   'gether',
#   'surprisingli',
#   'coupl',
#   'swear',
#   'give',
#   'pg13',
#   'rate',
#   'meet',
#   'good',
#   'peopl',
#   'want',
#   'help',
#   'journey',
#   'evil',
#   'peopl',
#   'want',
#   'destroy',
#   'fun',
#   'special',
#   'effect',
#   'direct',
#   'destin',
#   'cretton',
#   'chang',
#   'xcharact',
#   'creat',
#   'steve',
#   'englehart',
#   'jim',
#   'starlin',
#   'quit',
#   'good'],
#  ['realli',
#   'like',
#   'actor',
#   'spoke',
#   'nativ',
#   'languag',
#   'mandarin',
#   'wouldv',
#   'felt',
#   'american',
#   'otherwis',
#   'someth',
#   'unfinish',
#   'movi',
#   'im',
#   'sure',
#   'pace',
#   'alright',
#   'littl',
#   'slow',
#   'fast',
#   'time',
#   'far',
#   'storylin',
#   'go',
#   'excit',
#   'thought',
#   'would',
#   'fight',
#   'scene',
#   'great',
#   'though',
#   'especi',
#   'final',
#   'grand',
#   'battl',
#   'scene'],
#  ['worst',
#   'marvel',
#   'movi',
#   'seen',
#   'dateaft',
#   'see',
#   'movi',
#   'honestli',
#   'surpris',
#   'high',
#   'rate',
#   'watch',
#   'thing',
#   'movi',
#   'without',
#   'soul',
#   'charact',
#   'arent',
#   'build',
#   'enough',
#   'even',
#   '2',
#   'hour',
#   'run',
#   'time',
#   'movi',
#   'liter',
#   'got',
#   'noth',
#   'ten',
#   'ring',
#   'movi',
#   'becam',
#   'godzilla',
#   'v',
#   'king',
#   'kong',
#   'end',
#   'wast',
#   '2',
#   'hour',
#   'honestli',
#   'clueless',
#   'peopl',
#   'high',
#   'prais',
#   'movi',
#   'wast',
#   'opportun',
#   'creat',
#   'wonder',
#   'authent',
#   'world',
#   'asian',
#   'marvel',
#   'univers']]

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Write your code here
nltk.download('averaged_perceptron_tagger')
def pos(pos):
  pos_rev=[]
  for i in pos:
    tagged = nltk.pos_tag(i)
    pos_rev.append(tagged)
  return pos_rev


pos(Stemming_Lemmetize(stop_words(Tokenize(df["User Reviews"]))))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# ['got', 'to', 'admit', 'wasnt', 'particularly', 'blown', 'away', 'by', 'anything', 'in', 'the', 'movie', 'might', 'even', 'say', 'was', 'bored', 'by', 'itdont', 'get', 'me', 'wrong', 'it', 'is', 'a', 'spectacle', 'the', 'action', 'is', 'great', 'the', 'locations', 'are', 'nice', 'costume', 'design', 'sound', 'design', 'etc', 'but', 'it', 'is', 'overall', 'a', 'soft', 'release', 'not', 'worth', 'seeing', 'in', 'theaters', 'specially', 'as', 'a', 'followup', 'to', 'what', 'endgame', 'wasthe', 'biggest', 'problem', 'for', 'me', 'is', 'how', 'the', 'underwritten', 'lead', 'has', 'muddled', 'personality', 'for', 'reasons', 'covered', 'in', 'the', 'story', 'devoid', 'of', 'charm', 'personality', 'or', 'good', 'dialoguethe', 'next', 'issue', 'is', 'the', 'humor', 'which', 'didnt', 'land', 'for', 'me', 'not', 'once', 'the', 'supporting', 'lead', 'awkwafina', 'isnt', 'her', 'normal', 'loud', 'self', 'thats', 'supposed', 'to', 'be', 'funny', 'every', 'time', 'she', 'opens', 'her', 'mouth', 'her', 'role', 'is', 'very', 'supportive', 'and', 'a', 'little', 'dramatic', 'and', 'while', 'questioned', 'myself', 'why', 'was', 'she', 'even', 'there', 'for', 'it', 'doesnt', 'ultimately', 'matter', 'she', 'is', 'another', 'forgettable', 'character', 'that', 'is', 'given', 'more', 'importance', 'than', 'the', 'role', 'deservesfinally', 'the', 'third', 'act', 'is', 'weak', 'theres', 'a', 'balancing', 'problem', 'with', 'stakes', 'you', 'cant', 'feel', 'tension', 'or', 'weight', 'to', 'any', 'action', 'and', 'theres', 'a', 'lot', 'of', 'superficial', 'cant', 'do', 'it', 'until', 'they', 'canin', 'the', 'end', 'this', 'feels', 'like', 'a', 'very', 'safe', 'plot', 'written', 'in', 'a', 'way', 'to', 'appeal', 'to', 'china', 'considering', 'how', 'the', 'mandarin', 'is', 'portrayed', 'that', 'ends', 'up', 'appealing', 'to', 'no', 'one', 'specific', 'certainly', 'doesnt', 'feel', 'like', 'a', 'marvel', 'movie', 'but', 'it', 'was', 'bound', 'to', 'happen', 'if', 'we', 'are', 'to', 'be', 'introduced', 'to', 'different', 'aspects', 'of', 'the', 'narrative', 'but', 'it', 'also', 'doesnt', 'feel', 'like', 'a', 'comic', 'book', 'its', 'more', 'generic', 'than', 'that']
# ['the', 'characters', 'are', 'a', 'bit', 'incoherent', 'and', 'straight', 'up', 'contradict', 'their', 'own', 'characterizations', 'at', 'times', 'because', 'the', 'plot', 'needs', 'them', 'to', 'do', 'it', 'there', 'are', 'a', 'bunch', 'of', 'unneeded', 'deuxex', 'machina', 'or', 'conveniences', 'because', 'the', 'writers', 'trapped', 'themselves', 'into', 'corners', 'for', 'no', 'reason', 'thats', 'what', 'happens', 'when', 'you', 'get', 'the', '2021', 'mortal', 'kombat', 'ww84', 'and', 'the', 'expendables', 'writersalso', 'we', 'have', 'awkwafina', 'destroying', 'every', 'type', 'of', 'scene', 'dramatic', 'epic', 'and', 'also', 'the', 'comedic', 'ones', 'with', 'one', 'of', 'the', 'worst', 'acting', 'ive', 'ever', 'seen', 'and', 'a', 'same', 'type', 'of', 'joke', 'awkward', 'nonsense', 'over', 'and', 'over', 'from', 'start', 'to', 'finish', 'with', 'a', 'role', 'ridiculously', 'large', 'for', 'a', 'dumb', 'comic', 'reliefbut', 'liu', 'is', 'actually', 'pretty', 'good', 'as', 'a', 'lead', 'and', 'his', 'character', 'is', 'potentially', 'great', 'and', 'the', 'shangchworld', 'is', 'beautiful', 'and', 'it', 'has', 'everything', 'to', 'be', 'super', 'fun', 'to', 'watch', 'in', 'the', 'futurewithout', 'awkwafine', 'and', 'better', 'writers']
# ['destin', 'daniel', 'crettons', 'shangchand', 'the', 'legend', 'of', 'the', 'ten', 'rings', 'marks', 'a', 'bland', 'start', 'to', 'the', 'new', 'phase', 'of', 'marvel', 'cinematic', 'universe', 'it', 'is', 'a', 'spectacle', 'with', 'regards', 'to', 'action', 'sequence', 'and', 'fighting', 'choreography', 'but', 'the', 'film', 'misses', 'a', 'solid', 'storyline', 'for', 'an', 'origin', 'story', 'as', 'its', 'titular', 'character', 'lacks', 'personality', 'and', 'does', 'not', 'go', 'through', 'any', 'heroic', 'transformation', 'story', 'arc', 'simu', 'liu', 'has', 'a', 'strong', 'presence', 'as', 'shangchyet', 'he', 'is', 'overshadowed', 'by', 'many', 'of', 'his', 'more', 'experienced', 'costars']
# ['the', 'story', 'was', 'riddled', 'with', 'holes', 'and', 'plot', 'issues', 'since', 'when', 'does', 'awkwafinas', 'pedestrian', 'character', 'all', 'of', 'a', 'sudden', 'get', 'invited', 'to', 'become', 'part', 'of', 'the', 'mcu', 'team', 'whats', 'her', 'super', 'power', 'stupidity', 'dont', 'get', 'me', 'wrong', 'love', 'her', 'but', 'her', 'character', 'was', 'lazily', 'written', 'then', 'theres', 'the', 'whole', 'daddy', 'issues', 'dynamic', 'shang', 'is', 'with', 'him', 'then', 'against', 'then', 'with', 'etc', 'then', 'we', 'have', 'these', 'ridiculous', 'dragons', 'fighting', 'where', 'one', 'scores', 'some', 'power', 'crystals', 'and', 'becomes', 'stronger', 'this', 'is', 'just', 'infantile', 'lazy', 'writing', 'there', 'was', 'zero', 'shock', 'value', 'or', 'anything', 'spectacular', 'in', 'the', 'entire', 'runtime', 'with', 'tedious', 'long', 'middle', 'acts', 'and', 'a', 'bumbling', 'third', 'act', 'the', 'jokes', 'were', 'cliched', 'and', 'not', 'funny', 'the', 'funniest', 'parts', 'were', 'ben', 'kingsleys', 'character', 'of', 'whom', 'was', 'in', 'this', 'for', 'what', 'reasons', 'and', 'the', 'ending', 'to', 'go', 'karaoke', 'which', 'was', 'the', 'only', 'time', 'actually', 'cracked', 'a', 'chuckle', 'youd', 'think', 'with', 'three', 'writers', 'wed', 'have', 'something', 'cohesive', 'and', 'coherent', 'but', 'instead', 'of', 'a', 'marvel', 'superhero', 'story', 'we', 'got', 'a', 'disney', 'evil', 'vs', 'good', 'with', 'dragons', 'thrown', 'into', 'the', 'mix', 'its', 'as', 'if', 'they', 'tried', 'too', 'hard', 'to', 'create', 'the', 'asian', 'version', 'of', 'black', 'pantherits', 'a', 'shame', 'because', 'the', 'directing', 'and', 'cinematography', 'were', 'spot', 'on', 'and', 'great', 'svfx', 'although', 'a', 'little', 'overboard', 'with', 'the', 'cgie', 'dragons', 'the', 'martial', 'arts', 'choreography', 'was', 'outstanding', 'although', 'again', 'overboard', 'after', 'the', 'awesome', 'bus', 'scene', 'and', 'the', 'casting', 'and', 'performances', 'were', 'excellent', 'especially', 'leung', 'who', 'pretty', 'much', 'carried', 'the', 'film', 'on', 'his', 'shoulders', 'its', 'a', '710', 'from', 'me']
# ['everything', 'comes', 'in', 'it', 'beautiful', 'science', 'fiction', 'and', 'beautiful', 'mythical', 'creatures', 'sometimes', 'you', 'have', 'creatures', 'that', 'dont', 'seem', 'real', 'but', 'these', 'just', 'seemed', 'real', 'well', 'done', 'there', 'was', 'a', 'bit', 'of', 'avatar', 'feeling', 'in', 'it', 'fighting', 'for', 'the', 'safekeeping', 'of', 'peace', 'really', 'beautiful', 'and', 'selfacceptance', 'was', 'also', 'nicely', 'incorporated']
# ['ill', 'be', 'honest', 'marvel', 'movies', 'are', 'not', 'in', 'my', 'top', '20', 'or', 'even', '50', 'but', 'within', 'the', 'marvel', 'universe', 'would', 'say', 'that', 'shangchis', 'in', 'my', 'top', '5', 'know', 'its', 'blasphemy', 'and', 'all', 'that', 'but', 'think', 'about', 'it', 'is', 'it', 'better', 'than', 'iron', 'man', 'would', 'admit', 'yes', 'its', 'origin', 'story', 'is', 'arguably', 'better', 'and', 'its', 'characters', 'are', 'a', 'lot', 'deeper', 'the', 'mandarin', 'is', 'a', 'conflicted', 'man', 'with', 'evil', 'but', 'good', 'as', 'well', 'like', 'real', 'life', 'is', 'this', 'movie', 'better', 'than', 'the', 'avengers', 'or', 'ragnarok', 'or', 'infinity', 'wars', 'hard', 'to', 'say', 'which', 'means', 'its', 'right', 'up', 'there', 'with', 'the', 'best', 'of', 'marvel', 'in', 'my', 'opinionplus', 'im', 'a', 'sucker', 'for', 'chinese', 'movies', 'with', 'the', 'chinese', 'language', 'being', 'spoken', '1', 'of', 'my', 'favourite', 'of', 'all', 'times', 'if', 'not', 'my', 'absolute', 'favourite', 'is', 'of', 'course', 'hero', 'the', 'chinese', 'language', 'and', 'the', 'artistry', 'of', 'its', 'culture', 'are', 'magnificentall', 'in', 'all', 'well', 'done', 'marvel', 'director', 'destin', 'and', 'all', 'those', 'who', 'worked', 'to', 'make', 'this', 'movie', 'a', 'reality', 'this', 'is', 'not', 'just', 'your', 'average', 'summer', 'action', 'movie', 'its', 'close', 'to', 'being', 'a', 'masterpiece', 'and', 'the', 'humour', 'is', 'pretty', 'swell', 'toocheers']
# ['shangchis', 'a', 'boring', 'film', 'the', 'characters', 'were', 'okay', 'but', 'the', 'story', 'was', 'choppy', 'and', 'confusing', 'the', 'song', 'choices', 'were', 'odd', 'plus', 'this', 'movie', 'was', 'way', 'too', 'long', 'and', 'the', 'scene', 'at', 'the', 'end', 'had', 'me', 'practically', 'falling', 'asleep']
# ['watched', 'the', 'imax', 'version', 'best', 'solo', 'since', 'iron', 'man', '2008', 'had', 'no', 'expectations', 'of', 'this', 'before', 'but', 'the', 'movie', 'is', 'much', 'more', 'lively', 'enjoyed', 'every', 'moment', 'and', 'also', 'very', 'engaging', 'from', 'start', 'to', 'finish', 'a', 'kinda', 'cuteaction', 'movie', 'with', 'some', 'fun', 'stuffthis', 'is', 'the', 'first', 'movie', 'that', 'focuses', 'more', 'on', 'martial', 'arts', 'than', 'marvels', 'superpower', 'thing', 'love', 'to', 'see', 'a', 'mix', 'of', 'marvels', 'masterlevelcgwith', 'martial', 'art', 'kungfu', 'with', 'this', 'kind', 'of', 'visual', 'effect', 'marvel', 'nailed', 'it', 'againive', 'always', 'loved', 'marvels', 'casting', 'katy', 'is', 'too', 'perfect', 'for', 'her', 'role', 'loved', 'her', 'chemistry', 'with', 'shaun', 'also', 'laughed', 'out', 'loud', 'at', 'her', 'childish', 'stuffsjust', 'one', 'thing', 'not', 'a', 'big', 'deal', 'the', 'action', 'scene', 'of', 'dragon', 'riding', 'doesnt', 'fit', 'into', 'the', 'usual', 'marvel', 'movie', 'but', 'as', 'chinese', 'flavor', 'it', 'is', 'ok', 'except', 'for', 'this', 'the', 'cinematography', 'and', 'vfx', 'are', 'a', 'lot', 'mesmerizing']
# ['lets', 'agree', 'that', 'it', 'is', 'a', 'bad', 'movie', 'from', 'multiple', 'points', 'of', 'view', 'it', 'depends', 'a', 'lot', 'on', 'the', 'visual', 'effects', 'its', 'main', 'characters', 'can', 'be', 'funny', 'but', 'not', 'nice', 'the', 'story', 'does', 'not', 'generate', 'much', 'interest', 'and', 'we', 'have', 'seen', 'the', 'fights', 'many', 'times', 'and', 'in', 'a', 'better', 'way', 'in', 'almost', 'any', 'film', 'produced', 'in', 'hong', 'kong', 'indonesia', 'or', 'thailand', 'of', 'the', 'last', 'twenty', 'years', 'the', 'only', 'thing', 'that', 'saves', 'this', 'film', 'is', 'the', 'karaoke', 'scene', 'that', 'is', 'unexpectedly', 'welcome', 'the', 'rest', 'is', 'routine', 'mediocre', 'tiring', 'and', 'bland']
# ['as', 'far', 'as', 'visuals', 'go', 'this', 'movie', 'is', 'amazing', 'like', 'just', 'about', 'as', 'impressive', 'as', 'dune', 'its', 'filled', 'to', 'the', 'brim', 'with', 'eyecandythe', 'plotstory', 'however', 'is', 'mediocre', 'and', 'filled', 'with', 'plot', 'holes', 'the', 'characters', 'actions', 'are', 'often', 'unrealistic', 'and', 'they', 'will', 'often', 'just', 'stare', 'in', 'awe', 'at', 'their', 'friends', 'being', 'killed', 'instead', 'of', 'doing', 'the', 'realistic', 'thing', 'and', 'immediately', 'defending', 'their', 'friends', 'its', 'something', 'that', 'happens', 'like', '5', 'times', 'and', 'honestly', 'spoils', 'the', 'movie', 'for', 'me', 'if', 'characters', 'in', 'a', 'movie', 'dont', 'act', 'or', 'react', 'realistically', 'and', 'stare', 'at', 'something', 'like', 'a', 'braindead', 'zombie', 'like', 'their', 'friends', 'getting', 'killed', 'right', 'in', 'front', 'of', 'them', 'whilst', 'they', 'are', 'holding', 'a', 'gun', 'in', 'their', 'freeking', 'hands', 'then', 'its', 'just', 'really', 'terrible', 'scriptplot', 'writingoverall', 'the', 'movie', 'isnt', 'as', 'bad', 'as', 'antman', '2', 'but', 'its', 'not', 'far', 'behind', 'also', 'awkwafinas', 'acting', 'style', 'was', 'already', 'old', 'by', 'the', '2nd', 'movie', 'she', 'did', 'all', 'of', 'her', 'characters', 'in', 'movies', 'are', 'the', 'same', 'person', 'and', 'like', 'said', 'it', 'got', 'boring', 'after', 'the', '2nd', 'movie', 'roll', 'my', 'eyes', 'at', 'everything', 'awkwafinas', 'character', 'does', 'in', 'the', 'movieits', 'a', '510', 'movie', 'not', 'really', 'worth', 'a', 'watch', 'unless', 'youre', 'a', 'real', 'diehard', 'marvel', 'fan']
# ['rated', '810', 'language', 'english', 'source', 'hotstar', 'recommendedthe', 'story', 'and', 'making', 'is', 'worth', 'to', 'watch', 'in', 'big', 'screen', 'with', 'good', 'sound', 'system', 'the', 'first', 'half', 'is', 'filled', 'with', 'great', 'actions', 'and', 'funny', 'moments', 'and', 'it', 'get', 'into', 'serious', 'mode', 'in', 'the', 'second', 'halfthe', 'second', 'half', 'is', 'more', 'traditional', 'and', 'sentimentalthe', 'decent', 'story', 'and', 'colourful', 'visual', 'makes', 'this', 'so', 'grand', 'good', 'movie', 'to', 'watch', 'with', 'family']
# ['martial', 'arts', 'meets', 'the', 'mcu', 'in', 'shangchand', 'the', 'legend', 'of', 'the', 'ten', 'rings', 'more', 'crouching', 'tiger', 'than', 'jackie', 'chan', 'the', 'plot', 'for', 'the', 'film', 'is', 'kinda', 'humdrum', 'the', 'sort', 'of', 'mystical', 'eastern', 'fantasy', 'cobblers', 'that', 'practically', 'writes', 'itselfshangchis', 'the', 'son', 'of', 'immortal', 'powerhungry', 'warlord', 'xu', 'wenwu', 'tony', 'chiuwaleung', 'and', 'lfala', 'chen', 'a', 'warrior', 'woman', 'from', 'the', 'hidden', 'village', 'of', 'ta', 'lo', 'after', 'falling', 'in', 'love', 'with', 'land', 'becoming', 'a', 'father', 'wenwu', 'gives', 'up', 'his', 'wicked', 'ways', 'and', 'packs', 'away', 'the', 'ten', 'legendary', 'rings', 'that', 'gave', 'him', 'much', 'of', 'his', 'power', 'however', 'after', 'his', 'wife', 'is', 'killed', 'by', 'his', 'old', 'enemies', 'wenwu', 'once', 'again', 'wears', 'the', 'rings', 'and', 'trains', 'his', 'son', 'to', 'become', 'an', 'assassin', 'ashamed', 'of', 'what', 'he', 'has', 'become', 'shangchgoes', 'into', 'hiding', 'in', 'america', 'and', 'becomes', 'shaun', 'simu', 'liu', 'but', 'his', 'past', 'eventually', 'catches', 'up', 'with', 'him', 'when', 'his', 'father', 'sends', 'his', 'army', 'the', 'ten', 'rings', 'to', 'steal', 'the', 'pendants', 'given', 'to', 'him', 'and', 'his', 'sister', 'xialing', 'menger', 'zhang', 'by', 'their', 'mother', 'wenwu', 'requires', 'both', 'pendants', 'to', 'reveal', 'the', 'way', 'to', 'ta', 'lo', 'where', 'he', 'believes', 'that', 'his', 'wife', 'is', 'being', 'held', 'captive', 'by', 'her', 'peoplethis', 'marvel', 'movie', 'is', 'at', 'its', 'most', 'fun', 'before', 'the', 'plot', 'starts', 'to', 'get', 'in', 'the', 'way', 'and', 'the', 'cgbecomes', 'too', 'overbearing', 'and', 'intrusive', 'the', 'early', 'fight', 'scenes', 'a', 'battle', 'on', 'a', 'runaway', 'bus', 'against', 'a', 'henchman', 'known', 'as', 'razor', 'fist', 'and', 'a', 'fight', 'on', 'some', 'highrise', 'bamboo', 'scaffolding', 'deliver', 'lots', 'of', 'impressively', 'choreographed', 'action', 'that', 'will', 'please', 'both', 'martial', 'arts', 'fans', 'and', 'superhero', 'addicts', 'awkwafina', 'as', 'shangchis', 'loyal', 'friend', 'katy', 'provides', 'some', 'comic', 'relief', 'but', 'also', 'gets', 'stuck', 'in', 'with', 'the', 'actionunfortunately', 'the', 'film', 'quickly', 'goes', 'downhill', 'after', 'the', 'good', 'guys', 'make', 'their', 'way', 'to', 'ta', 'lo', 'with', 'a', 'little', 'help', 'from', 'tony', 'slattery', 'see', 'iron', 'man', '3', 'and', 'a', 'furry', 'winged', 'creature', 'with', 'no', 'face', 'the', 'inevitable', 'battle', 'between', 'the', 'villagers', 'and', 'wenwus', 'army', 'is', 'typical', 'overblown', 'marvel', 'mayhem', 'but', 'the', 'massive', 'cgtsunamarrives', 'when', 'wenwu', 'opens', 'the', 'interdimensional', 'gate', 'that', 'he', 'thinks', 'is', 'holding', 'lprisoner', 'instead', 'of', 'releasing', 'his', 'wife', 'he', 'frees', 'a', 'swarm', 'of', 'flying', 'tentacled', 'soulsuckers', 'and', 'their', 'big', 'bad', 'boss', 'the', 'dweller', 'fortunately', 'for', 'the', 'ta', 'lo', 'people', 'they', 'have', 'a', 'massive', 'magical', 'dragon', 'on', 'their', 'side', 'which', 'wakes', 'up', 'and', 'adds', 'to', 'the', 'digital', 'whizzbangeryas', 'technically', 'impressive', 'as', 'the', 'special', 'effects', 'are', 'found', 'the', 'second', 'half', 'of', 'the', 'film', 'visually', 'overwhelming', 'yet', 'remarkably', 'uninvolving', 'a', 'whirlwind', 'of', 'pixels', 'and', 'noisy', 'action', 'without', 'much', 'substance510', 'it', 'was', 'nice', 'to', 'see', 'hkchinese', 'stars', 'michelle', 'yeoh', 'tony', 'leung', 'and', 'yuen', 'wah', 'together', 'in', 'a', 'marvel', 'movie', 'just', 'wish', 'it', 'had', 'been', 'a', 'better', 'one']
# ['shangchand', 'the', 'legend', 'of', 'the', 'ten', 'rings', 'takes', 'place', 'some', 'time', 'after', 'avengers', 'endgame', 'is', 'the', 'beginning', 'of', 'phase', 'four', 'of', 'the', 'marvel', 'cinematic', 'universeshangchis', 'an', 'alright', 'movie', 'it', 'has', 'some', 'great', 'fight', 'scenes', 'with', 'some', 'incredible', 'fight', 'choreography', 'and', 'epic', 'largescale', 'battles', 'it', 'is', 'also', 'has', 'some', 'good', 'comedic', 'scenes', 'that', 'made', 'me', 'laugh', 'a', 'couple', 'of', 'times', 'where', 'shangchsuffers', 'is', 'when', 'it', 'comes', 'to', 'the', 'plot', 'didnt', 'find', 'the', 'story', 'very', 'compelling', 'and', 'didnt', 'get', 'that', 'attached', 'to', 'the', 'characters', 'its', 'a', 'story', 'that', 'feel', 'has', 'been', 'done', 'many', 'times', 'beforeshangchwasnt', 'for', 'me', 'but', 'its', 'comedy', 'and', 'fight', 'scenes', 'make', 'up', 'for', 'some', 'of', 'its', 'flaws', 'if', 'you', 'are', 'familiar', 'with', 'the', 'marvel', 'franchise', 'assume', 'you', 'somewhat', 'know', 'what', 'to', 'expect', 'and', 'for', 'you', 'can', 'recommend', 'it', 'although', 'the', 'movie', 'isnt', 'that', 'great', 'still', 'think', 'its', 'good', 'enough', 'to', 'the', 'point', 'of', 'where', 'its', 'worth', 'watching', 'just', 'to', 'keep', 'up', 'with', 'the', 'larger', 'plot', 'of', 'the', 'mcu', 'for', 'those', 'not', 'invested', 'in', 'the', 'mcu', 'dont', 'believe', 'that', 'this', 'movie', 'is', 'the', 'one', 'you', 'should', 'start', 'with']
# ['the', 'best', 'marvel', 'movie', 'after', 'endgame', 'the', 'story', 'is', 'a', 'bit', 'cliché', 'but', 'the', 'rest', 'is', 'absolutely', 'amazing', 'the', 'fight', 'scenes', 'are', 'the', 'best', 'in', 'the', 'mcu', 'in', 'my', 'opinion', 'simu', 'liu', 'as', 'shangchis', 'perfectly', 'chosen', 'and', 'all', 'the', 'other', 'characters', 'are', 'nice', 'and', 'the', 'all', 'the', 'actors', 'do', 'a', 'good', 'job', 'act', '3', 'is', 'on', 'another', 'level', 'that', 'we', 'havent', 'seen', 'before', 'in', 'mcu', 'and', 'the', 'visual', 'effects', 'are', 'spectacular', 'by', 'far', 'one', 'of', 'the', 'best', 'origin', 'stories', 'from', 'marvel']
# ['it', 'had', 'potential', 'but', 'marvel', 'has', 'this', 'tendency', 'of', 'degrading', 'everything', 'into', 'mindless', 'comedythings', 'just', 'happen', 'to', 'an', 'extent', 'where', 'awkwafina', 'is', 'now', 'an', 'avenger', 'im', 'getting', 'too', 'old', 'for', 'this', 'st']
# ['really', 'entertaining', 'movie', 'actors', 'were', 'great', 'simu', 'liu', 'brought', 'it', 'big', 'time', 'he', 'is', 'excellent', 'as', 'the', 'main', 'character', 'awkwafina', 'is', 'hilarious', 'and', 'wish', 'she', 'had', 'more', 'screen', 'time', 'as', 'far', 'as', 'marvel', 'movies', 'goes', 'its', 'not', 'the', 'best', 'one', 'but', 'still', 'very', 'good']
# ['this', 'is', 'the', 'story', 'of', 'ten', 'rings', 'weapons', 'used', 'for', 'thousands', 'of', 'years', 'to', 'take', 'power', 'and', 'control', 'shang', 'ch', 'simu', 'liu', 'as', 'chang', 'x', 'accidentally', 'gets', 'pulled', 'into', 'the', 'history', 'and', 'cant', 'turn', 'back', 'costars', 'awkwafina', 'tony', 'leung', 'both', 'winners', 'of', 'tons', 'of', 'film', 'festival', 'awards', 'also', 'ben', 'kingsley', 'oscar', 'for', 'gandhalthough', 'he', 'looks', 'so', 'different', 'you', 'may', 'not', 'recognize', 'kingsley', 'in', 'his', 'role', 'its', 'a', 'marvel', 'story', 'from', 'disney', 'so', 'theres', 'a', 'good', 'mix', 'of', 'adventure', 'violence', 'animation', 'levitation', 'and', 'some', 'jokes', 'sprinkled', 'here', 'and', 'there', 'the', 'bad', 'guys', 'are', 'collecting', 'the', 'pendants', 'with', 'the', 'power', 'and', 'can', 'not', 'be', 'allowed', 'to', 'gether', 'them', 'all', 'surprisingly', 'a', 'couple', 'swears', 'giving', 'it', 'the', 'pg13', 'rating', 'they', 'meet', 'good', 'people', 'that', 'want', 'to', 'help', 'them', 'on', 'their', 'journey', 'and', 'evil', 'people', 'that', 'want', 'to', 'destroy', 'them', 'some', 'fun', 'special', 'effects', 'directed', 'by', 'destin', 'cretton', 'chang', 'xcharacter', 'created', 'by', 'steve', 'englehart', 'jim', 'starlin', 'its', 'quite', 'good']
# ['really', 'liked', 'that', 'the', 'actors', 'spoke', 'their', 'native', 'language', 'mandarin', 'because', 'it', 'wouldve', 'felt', 'too', 'americanized', 'otherwise', 'but', 'there', 'was', 'something', 'unfinished', 'about', 'this', 'movie', 'and', 'im', 'not', 'sure', 'what', 'it', 'is', 'the', 'pacing', 'was', 'alright', 'a', 'little', 'too', 'slow', 'or', 'fast', 'at', 'times', 'and', 'as', 'far', 'as', 'storylines', 'go', 'it', 'was', 'not', 'as', 'exciting', 'as', 'thought', 'it', 'would', 'be', 'the', 'fight', 'scenes', 'were', 'great', 'though', 'especially', 'the', 'final', 'grand', 'battle', 'scene']
# ['this', 'is', 'the', 'worst', 'marvel', 'movie', 'have', 'seen', 'to', 'dateafter', 'seeing', 'the', 'movie', 'was', 'honestly', 'surprised', 'by', 'all', 'the', 'high', 'ratings', 'did', 'we', 'watch', 'the', 'same', 'thing', 'the', 'movie', 'is', 'without', 'a', 'soul', 'characters', 'arent', 'build', 'up', 'enough', 'even', 'with', 'a', '2', 'hour', 'run', 'time', 'the', 'movie', 'literally', 'got', 'nothing', 'to', 'do', 'with', 'the', 'ten', 'rings', 'movie', 'became', 'godzilla', 'vs', 'king', 'kong', 'at', 'the', 'end', 'waste', 'of', '2', 'hours', 'honestly', 'clueless', 'why', 'people', 'high', 'praised', 'for', 'this', 'movie', 'what', 'a', 'waste', 'of', 'opportunity', 'to', 'create', 'a', 'wonderful', 'and', 'authentic', 'world', 'for', 'asian', 'marvel', 'universe']
# [[('got', 'VBD'),
#   ('admit', 'JJ'),
#   ('wasnt', 'IN'),
#   ('particularli', 'JJ'),
#   ('blown', 'VBN'),
#   ('away', 'RB'),
#   ('anyth', 'JJ'),
#   ('movi', 'NN'),
#   ('might', 'MD'),
#   ('even', 'RB'),
#   ('say', 'VB'),
#   ('bore', 'NN'),
#   ('itdont', 'JJ'),
#   ('get', 'NN'),
#   ('wrong', 'JJ'),
#   ('spectacl', 'JJ'),
#   ('action', 'NN'),
#   ('great', 'JJ'),
#   ('locat', 'JJ'),
#   ('nice', 'JJ'),
#   ('costum', 'NN'),
#   ('design', 'NN'),
#   ('sound', 'NN'),
#   ('design', 'NN'),
#   ('etc', 'FW'),
#   ('overal', 'JJ'),
#   ('soft', 'JJ'),
#   ('releas', 'NNS'),
#   ('worth', 'JJ'),
#   ('see', 'VBP'),
#   ('theater', 'JJ'),
#   ('special', 'JJ'),
#   ('followup', 'NN'),
#   ('endgam', 'NN'),
#   ('wasth', 'VBP'),
#   ('biggest', 'JJS'),
#   ('problem', 'NN'),
#   ('underwritten', 'JJ'),
#   ('lead', 'NN'),
#   ('muddl', 'NN'),
#   ('person', 'NN'),
#   ('reason', 'NN'),
#   ('cover', 'NN'),
#   ('stori', 'NN'),
#   ('devoid', 'JJ'),
#   ('charm', 'NN'),
#   ('person', 'NN'),
#   ('good', 'JJ'),
#   ('dialogueth', 'NN'),
#   ('next', 'JJ'),
#   ('issu', 'NN'),
#   ('humor', 'NN'),
#   ('didnt', 'NN'),
#   ('land', 'NN'),
#   ('support', 'NN'),
#   ('lead', 'VBD'),
#   ('awkwafina', 'RB'),
#   ('isnt', 'JJ'),
#   ('normal', 'JJ'),
#   ('loud', 'JJ'),
#   ('self', 'NN'),
#   ('that', 'WDT'),
#   ('suppos', 'VBZ'),
#   ('funni', 'JJ'),
#   ('everi', 'JJ'),
#   ('time', 'NN'),
#   ('open', 'JJ'),
#   ('mouth', 'NN'),
#   ('role', 'NN'),
#   ('support', 'NN'),
#   ('littl', 'VBD'),
#   ('dramat', 'JJ'),
#   ('question', 'NN'),
#   ('even', 'RB'),
#   ('doesnt', 'VBZ'),
#   ('ultim', 'JJ'),
#   ('matter', 'NN'),
#   ('anoth', 'DT'),
#   ('forgett', 'JJ'),
#   ('charact', 'NN'),
#   ('given', 'VBN'),
#   ('import', 'JJ'),
#   ('role', 'NN'),
#   ('deservesfin', 'NN'),
#   ('third', 'JJ'),
#   ('act', 'NN'),
#   ('weak', 'JJ'),
#   ('there', 'RB'),
#   ('balanc', 'NN'),
#   ('problem', 'NN'),
#   ('stake', 'NN'),
#   ('cant', 'NN'),
#   ('feel', 'VB'),
#   ('tension', 'NN'),
#   ('weight', 'WRB'),
#   ('action', 'NN'),
#   ('there', 'RB'),
#   ('lot', 'VBZ'),
#   ('superfici', 'JJ'),
#   ('cant', 'NN'),
#   ('canin', 'JJ'),
#   ('end', 'NN'),
#   ('feel', 'NN'),
#   ('like', 'IN'),
#   ('safe', 'JJ'),
#   ('plot', 'NN'),
#   ('written', 'VBN'),
#   ('way', 'NN'),
#   ('appeal', 'JJ'),
#   ('china', 'NN'),
#   ('consid', 'NN'),
#   ('mandarin', 'NN'),
#   ('portray', 'JJ'),
#   ('end', 'NN'),
#   ('appeal', 'NN'),
#   ('one', 'CD'),
#   ('specif', 'NN'),
#   ('certainli', 'NN'),
#   ('doesnt', 'VBP'),
#   ('feel', 'NN'),
#   ('like', 'IN'),
#   ('marvel', 'NN'),
#   ('movi', 'NN'),
#   ('bound', 'IN'),
#   ('happen', 'JJ'),
#   ('introduc', 'NN'),
#   ('differ', 'NN'),
#   ('aspect', 'NN'),
#   ('narr', 'NN'),
#   ('also', 'RB'),
#   ('doesnt', 'VBP'),
#   ('feel', 'NNS'),
#   ('like', 'IN'),
#   ('comic', 'JJ'),
#   ('book', 'NN'),
#   ('gener', 'NN')],
#  [('charact', 'JJ'),
#   ('bit', 'NN'),
#   ('incoher', 'JJ'),
#   ('straight', 'JJ'),
#   ('contradict', 'NN'),
#   ('character', 'NN'),
#   ('time', 'NN'),
#   ('plot', 'NN'),
#   ('need', 'VBP'),
#   ('bunch', 'JJ'),
#   ('unneed', 'JJ'),
#   ('deuxex', 'NN'),
#   ('machina', 'NN'),
#   ('conveni', 'VBP'),
#   ('writer', 'NN'),
#   ('trap', 'NN'),
#   ('corner', 'NN'),
#   ('reason', 'NN'),
#   ('that', 'WDT'),
#   ('happen', 'VBZ'),
#   ('get', 'VB'),
#   ('2021', 'CD'),
#   ('mortal', 'JJ'),
#   ('kombat', 'NN'),
#   ('ww84', 'NN'),
#   ('expend', 'VBP'),
#   ('writersalso', 'NN'),
#   ('awkwafina', 'NN'),
#   ('destroy', 'NN'),
#   ('everi', 'NN'),
#   ('type', 'JJ'),
#   ('scene', 'NN'),
#   ('dramat', 'NN'),
#   ('epic', 'NN'),
#   ('also', 'RB'),
#   ('comed', 'VBD'),
#   ('one', 'CD'),
#   ('one', 'CD'),
#   ('worst', 'WDT'),
#   ('act', 'NN'),
#   ('ive', 'JJ'),
#   ('ever', 'RB'),
#   ('seen', 'VBN'),
#   ('type', 'NN'),
#   ('joke', 'NN'),
#   ('awkward', 'NN'),
#   ('nonsens', 'VBZ'),
#   ('start', 'JJ'),
#   ('finish', 'JJ'),
#   ('role', 'NN'),
#   ('ridicul', 'NN'),
#   ('larg', 'FW'),
#   ('dumb', 'JJ'),
#   ('comic', 'JJ'),
#   ('reliefbut', 'NN'),
#   ('liu', 'VBZ'),
#   ('actual', 'JJ'),
#   ('pretti', 'RB'),
#   ('good', 'JJ'),
#   ('lead', 'NN'),
#   ('charact', 'NN'),
#   ('potenti', 'JJ'),
#   ('great', 'JJ'),
#   ('shangchworld', 'NN'),
#   ('beauti', 'NN'),
#   ('everyth', 'FW'),
#   ('super', 'JJ'),
#   ('fun', 'NN'),
#   ('watch', 'NN'),
#   ('futurewithout', 'NN'),
#   ('awkwafin', 'NN'),
#   ('better', 'RBR'),
#   ('writer', 'NN')],
#  [('destin', 'NN'),
#   ('daniel', 'VBZ'),
#   ('cretton', 'JJ'),
#   ('shangchand', 'NN'),
#   ('legend', 'VBP'),
#   ('ten', 'JJ'),
#   ('ring', 'VBG'),
#   ('mark', 'NN'),
#   ('bland', 'VB'),
#   ('start', 'JJ'),
#   ('new', 'JJ'),
#   ('phase', 'NN'),
#   ('marvel', 'NN'),
#   ('cinemat', 'NN'),
#   ('univers', 'NNS'),
#   ('spectacl', 'VBP'),
#   ('regard', 'JJ'),
#   ('action', 'NN'),
#   ('sequenc', 'NN'),
#   ('fight', 'NN'),
#   ('choreographi', 'NN'),
#   ('film', 'NN'),
#   ('miss', 'VBP'),
#   ('solid', 'JJ'),
#   ('storylin', 'NN'),
#   ('origin', 'NN'),
#   ('stori', 'VBD'),
#   ('titular', 'JJ'),
#   ('charact', 'NN'),
#   ('lack', 'NN'),
#   ('person', 'NN'),
#   ('go', 'VBP'),
#   ('heroic', 'JJ'),
#   ('transform', 'NN'),
#   ('stori', 'NN'),
#   ('arc', 'NN'),
#   ('simu', 'NN'),
#   ('liu', 'NN'),
#   ('strong', 'JJ'),
#   ('presenc', 'NN'),
#   ('shangchyet', 'NN'),
#   ('overshadow', 'NN'),
#   ('mani', 'NN'),
#   ('experienc', 'NN'),
#   ('costar', 'NN')],
#  [('stori', 'JJ'),
#   ('riddl', 'NN'),
#   ('hole', 'NN'),
#   ('plot', 'NN'),
#   ('issu', 'NN'),
#   ('sinc', 'NN'),
#   ('awkwafina', 'NN'),
#   ('pedestrian', 'JJ'),
#   ('charact', 'NN'),
#   ('sudden', 'JJ'),
#   ('get', 'NN'),
#   ('invit', 'NN'),
#   ('becom', 'IN'),
#   ('part', 'NN'),
#   ('mcu', 'NN'),
#   ('team', 'NN'),
#   ('what', 'WP'),
#   ('super', 'VBZ'),
#   ('power', 'NN'),
#   ('stupid', 'JJ'),
#   ('dont', 'NN'),
#   ('get', 'VB'),
#   ('wrong', 'JJ'),
#   ('love', 'VB'),
#   ('charact', 'JJ'),
#   ('lazili', 'JJ'),
#   ('written', 'VBN'),
#   ('there', 'EX'),
#   ('whole', 'JJ'),
#   ('daddi', 'NN'),
#   ('issu', 'NN'),
#   ('dynam', 'NN'),
#   ('shang', 'NN'),
#   ('etc', 'FW'),
#   ('ridicul', 'NN'),
#   ('dragon', 'NN'),
#   ('fight', 'VBD'),
#   ('one', 'CD'),
#   ('score', 'NN'),
#   ('power', 'NN'),
#   ('crystal', 'NN'),
#   ('becom', 'NN'),
#   ('stronger', 'JJR'),
#   ('infantil', 'NN'),
#   ('lazi', 'RBR'),
#   ('write', 'JJ'),
#   ('zero', 'NN'),
#   ('shock', 'NN'),
#   ('valu', 'NN'),
#   ('anyth', 'IN'),
#   ('spectacular', 'JJ'),
#   ('entir', 'NN'),
#   ('runtim', 'NN'),
#   ('tediou', 'NN'),
#   ('long', 'RB'),
#   ('middl', 'JJ'),
#   ('act', 'NN'),
#   ('bumbl', 'IN'),
#   ('third', 'JJ'),
#   ('act', 'NN'),
#   ('joke', 'VBD'),
#   ('clich', 'JJ'),
#   ('funni', 'NN'),
#   ('funniest', 'JJS'),
#   ('part', 'NN'),
#   ('ben', 'NN'),
#   ('kingsley', 'NNP'),
#   ('charact', 'NN'),
#   ('reason', 'NN'),
#   ('end', 'NN'),
#   ('go', 'VB'),
#   ('karaok', 'JJ'),
#   ('time', 'NN'),
#   ('actual', 'JJ'),
#   ('crack', 'NN'),
#   ('chuckl', 'NN'),
#   ('youd', 'NN'),
#   ('think', 'VBP'),
#   ('three', 'CD'),
#   ('writer', 'NN'),
#   ('wed', 'VBD'),
#   ('someth', 'JJ'),
#   ('cohes', 'NNS'),
#   ('coher', 'VBP'),
#   ('instead', 'RB'),
#   ('marvel', 'JJ'),
#   ('superhero', 'NN'),
#   ('stori', 'NN'),
#   ('got', 'VBD'),
#   ('disney', 'JJ'),
#   ('evil', 'JJ'),
#   ('v', 'NN'),
#   ('good', 'JJ'),
#   ('dragon', 'NN'),
#   ('thrown', 'IN'),
#   ('mix', 'JJ'),
#   ('tri', 'JJ'),
#   ('hard', 'JJ'),
#   ('creat', 'NN'),
#   ('asian', 'JJ'),
#   ('version', 'NN'),
#   ('black', 'JJ'),
#   ('pantherit', 'NN'),
#   ('shame', 'NN'),
#   ('direct', 'JJ'),
#   ('cinematographi', 'NN'),
#   ('spot', 'NN'),
#   ('great', 'JJ'),
#   ('svfx', 'JJ'),
#   ('although', 'IN'),
#   ('littl', 'JJ'),
#   ('overboard', 'JJ'),
#   ('cgie', 'NN'),
#   ('dragon', 'NN'),
#   ('martial', 'JJ'),
#   ('art', 'NN'),
#   ('choreographi', 'NN'),
#   ('outstand', 'VBP'),
#   ('although', 'IN'),
#   ('overboard', 'NN'),
#   ('awesom', 'NN'),
#   ('bu', 'JJ'),
#   ('scene', 'NN'),
#   ('cast', 'VBD'),
#   ('perform', 'JJ'),
#   ('excel', 'NN'),
#   ('especi', 'NN'),
#   ('leung', 'VBD'),
#   ('pretti', 'RB'),
#   ('much', 'JJ'),
#   ('carri', 'NN'),
#   ('film', 'NN'),
#   ('shoulder', 'NN'),
#   ('710', 'CD')],
#  [('everyth', 'JJ'),
#   ('come', 'VB'),
#   ('beauti', 'NN'),
#   ('scienc', 'JJ'),
#   ('fiction', 'NN'),
#   ('beauti', 'NN'),
#   ('mythic', 'JJ'),
#   ('creatur', 'NN'),
#   ('sometim', 'NN'),
#   ('creatur', 'NN'),
#   ('dont', 'NN'),
#   ('seem', 'VBP'),
#   ('real', 'JJ'),
#   ('seem', 'JJ'),
#   ('real', 'JJ'),
#   ('well', 'RB'),
#   ('done', 'VBN'),
#   ('bit', 'NN'),
#   ('avatar', 'JJ'),
#   ('feel', 'NN'),
#   ('fight', 'RB'),
#   ('safekeep', 'JJ'),
#   ('peac', 'NN'),
#   ('realli', 'NN'),
#   ('beauti', 'NN'),
#   ('selfaccept', 'NN'),
#   ('also', 'RB'),
#   ('nice', 'JJ'),
#   ('incorpor', 'NN')],
#  [('ill', 'JJ'),
#   ('honest', 'JJS'),
#   ('marvel', 'NN'),
#   ('movi', 'NN'),
#   ('top', 'JJ'),
#   ('20', 'CD'),
#   ('even', 'RB'),
#   ('50', 'CD'),
#   ('within', 'IN'),
#   ('marvel', 'NN'),
#   ('univers', 'NNS'),
#   ('would', 'MD'),
#   ('say', 'VB'),
#   ('shangchi', 'JJ'),
#   ('top', 'JJ'),
#   ('5', 'CD'),
#   ('know', 'VBP'),
#   ('blasphemi', 'NN'),
#   ('think', 'VBP'),
#   ('better', 'JJR'),
#   ('iron', 'NN'),
#   ('man', 'NN'),
#   ('would', 'MD'),
#   ('admit', 'VB'),
#   ('ye', 'JJR'),
#   ('origin', 'NN'),
#   ('stori', 'NN'),
#   ('arguabl', 'VBP'),
#   ('better', 'JJR'),
#   ('charact', 'NN'),
#   ('lot', 'NN'),
#   ('deeper', 'JJR'),
#   ('mandarin', 'NN'),
#   ('conflict', 'NN'),
#   ('man', 'NN'),
#   ('evil', 'RB'),
#   ('good', 'JJ'),
#   ('well', 'RB'),
#   ('like', 'IN'),
#   ('real', 'JJ'),
#   ('life', 'NN'),
#   ('movi', 'NN'),
#   ('better', 'RBR'),
#   ('aveng', 'NN'),
#   ('ragnarok', 'JJ'),
#   ('infin', 'JJ'),
#   ('war', 'NN'),
#   ('hard', 'JJ'),
#   ('say', 'VBP'),
#   ('mean', 'JJ'),
#   ('right', 'JJ'),
#   ('best', 'JJS'),
#   ('marvel', 'NN'),
#   ('opinionplu', 'NN'),
#   ('im', 'NN'),
#   ('sucker', 'NN'),
#   ('chines', 'NNS'),
#   ('movi', 'VBP'),
#   ('chines', 'NNS'),
#   ('languag', 'VBP'),
#   ('spoken', 'JJ'),
#   ('1', 'CD'),
#   ('favourit', 'JJ'),
#   ('time', 'NN'),
#   ('absolut', 'JJ'),
#   ('favourit', 'NN'),
#   ('cours', 'NNS'),
#   ('hero', 'VBP'),
#   ('chines', 'NNS'),
#   ('languag', 'RBR'),
#   ('artistri', 'RB'),
#   ('cultur', 'JJ'),
#   ('magnificental', 'NN'),
#   ('well', 'RB'),
#   ('done', 'VBN'),
#   ('marvel', 'NN'),
#   ('director', 'NN'),
#   ('destin', 'NN'),
#   ('work', 'NN'),
#   ('make', 'VBP'),
#   ('movi', 'NN'),
#   ('realiti', 'NN'),
#   ('averag', 'NN'),
#   ('summer', 'NN'),
#   ('action', 'NN'),
#   ('movi', 'NN'),
#   ('close', 'JJ'),
#   ('masterpiec', 'NNS'),
#   ('humour', 'VBP'),
#   ('pretti', 'NNS'),
#   ('swell', 'VBP'),
#   ('toocheer', 'NN')],
#  [('shangchi', 'NNS'),
#   ('bore', 'VBD'),
#   ('film', 'NN'),
#   ('charact', 'NN'),
#   ('okay', 'IN'),
#   ('stori', 'JJ'),
#   ('choppi', 'NN'),
#   ('confus', 'NN'),
#   ('song', 'NN'),
#   ('choic', 'NN'),
#   ('odd', 'JJ'),
#   ('plu', 'NN'),
#   ('movi', 'JJ'),
#   ('way', 'NN'),
#   ('long', 'JJ'),
#   ('scene', 'JJ'),
#   ('end', 'NN'),
#   ('practic', 'JJ'),
#   ('fall', 'NN'),
#   ('asleep', 'NN')],
#  [('watch', 'NN'),
#   ('imax', 'NN'),
#   ('version', 'NN'),
#   ('best', 'JJS'),
#   ('solo', 'NN'),
#   ('sinc', 'NN'),
#   ('iron', 'NN'),
#   ('man', 'NN'),
#   ('2008', 'CD'),
#   ('expect', 'VBP'),
#   ('movi', 'VBN'),
#   ('much', 'JJ'),
#   ('live', 'JJ'),
#   ('enjoy', 'NN'),
#   ('everi', 'JJ'),
#   ('moment', 'NN'),
#   ('also', 'RB'),
#   ('engag', 'JJ'),
#   ('start', 'VBP'),
#   ('finish', 'JJ'),
#   ('kinda', 'NN'),
#   ('cuteact', 'NN'),
#   ('movi', 'NN'),
#   ('fun', 'NN'),
#   ('stuffthi', 'NN'),
#   ('first', 'RB'),
#   ('movi', 'VBZ'),
#   ('focu', 'JJ'),
#   ('martial', 'JJ'),
#   ('art', 'NN'),
#   ('marvel', 'NN'),
#   ('superpow', 'JJ'),
#   ('thing', 'NN'),
#   ('love', 'VB'),
#   ('see', 'NN'),
#   ('mix', 'JJ'),
#   ('marvel', 'NN'),
#   ('masterlevelcgwith', 'NN'),
#   ('martial', 'JJ'),
#   ('art', 'NN'),
#   ('kungfu', 'NN'),
#   ('kind', 'NN'),
#   ('visual', 'JJ'),
#   ('effect', 'NN'),
#   ('marvel', 'NN'),
#   ('nail', 'NN'),
#   ('again', 'RB'),
#   ('alway', 'RB'),
#   ('love', 'VB'),
#   ('marvel', 'NN'),
#   ('cast', 'NN'),
#   ('kati', 'NN'),
#   ('perfect', 'JJ'),
#   ('role', 'NN'),
#   ('love', 'NN'),
#   ('chemistri', 'NN'),
#   ('shaun', 'NN'),
#   ('also', 'RB'),
#   ('laugh', 'JJ'),
#   ('loud', 'JJ'),
#   ('childish', 'NN'),
#   ('stuffsjust', 'VBP'),
#   ('one', 'CD'),
#   ('thing', 'NN'),
#   ('big', 'JJ'),
#   ('deal', 'NN'),
#   ('action', 'NN'),
#   ('scene', 'NN'),
#   ('dragon', 'NN'),
#   ('ride', 'NN'),
#   ('doesnt', 'NN'),
#   ('fit', 'VBP'),
#   ('usual', 'JJ'),
#   ('marvel', 'NN'),
#   ('movi', 'NN'),
#   ('chines', 'NNS'),
#   ('flavor', 'VBP'),
#   ('ok', 'JJ'),
#   ('except', 'IN'),
#   ('cinematographi', 'JJ'),
#   ('vfx', 'NN'),
#   ('lot', 'NN'),
#   ('mesmer', 'NN')],
#  [('let', 'VB'),
#   ('agre', 'PRP'),
#   ('bad', 'JJ'),
#   ('movi', 'JJ'),
#   ('multipl', 'NN'),
#   ('point', 'NN'),
#   ('view', 'NN'),
#   ('depend', 'VBP'),
#   ('lot', 'NN'),
#   ('visual', 'JJ'),
#   ('effect', 'NN'),
#   ('main', 'JJ'),
#   ('charact', 'NN'),
#   ('funni', 'JJ'),
#   ('nice', 'JJ'),
#   ('stori', 'NN'),
#   ('gener', 'RB'),
#   ('much', 'JJ'),
#   ('interest', 'NN'),
#   ('seen', 'VBN'),
#   ('fight', 'RB'),
#   ('mani', 'JJ'),
#   ('time', 'NN'),
#   ('better', 'RBR'),
#   ('way', 'NN'),
#   ('almost', 'RB'),
#   ('film', 'NN'),
#   ('produc', 'NN'),
#   ('hong', 'NN'),
#   ('kong', 'NN'),
#   ('indonesia', 'NN'),
#   ('thailand', 'NN'),
#   ('last', 'JJ'),
#   ('twenti', 'JJ'),
#   ('year', 'NN'),
#   ('thing', 'NN'),
#   ('save', 'VBP'),
#   ('film', 'NN'),
#   ('karaok', 'NNS'),
#   ('scene', 'VBP'),
#   ('unexpectedli', 'JJ'),
#   ('welcom', 'NN'),
#   ('rest', 'NN'),
#   ('routin', 'NN'),
#   ('mediocr', 'NN'),
#   ('tire', 'NN'),
#   ('bland', 'NN')],
#  [('far', 'RB'),
#   ('visual', 'JJ'),
#   ('go', 'VBP'),
#   ('movi', 'JJ'),
#   ('amaz', 'NN'),
#   ('like', 'IN'),
#   ('impress', 'NN'),
#   ('dune', 'NN'),
#   ('fill', 'NN'),
#   ('brim', 'JJ'),
#   ('eyecandyth', 'NN'),
#   ('plotstori', 'NN'),
#   ('howev', 'NN'),
#   ('mediocr', 'NN'),
#   ('fill', 'NN'),
#   ('plot', 'NN'),
#   ('hole', 'NN'),
#   ('charact', 'JJ'),
#   ('action', 'NN'),
#   ('often', 'RB'),
#   ('unrealist', 'JJ'),
#   ('often', 'RB'),
#   ('stare', 'JJ'),
#   ('awe', 'JJ'),
#   ('friend', 'NN'),
#   ('kill', 'NN'),
#   ('instead', 'RB'),
#   ('realist', 'JJ'),
#   ('thing', 'NN'),
#   ('immedi', 'JJ'),
#   ('defend', 'VBP'),
#   ('friend', 'NN'),
#   ('someth', 'NN'),
#   ('happen', 'VBP'),
#   ('like', 'IN'),
#   ('5', 'CD'),
#   ('time', 'NN'),
#   ('honestli', 'JJ'),
#   ('spoil', 'NN'),
#   ('movi', 'NN'),
#   ('charact', 'NN'),
#   ('movi', 'FW'),
#   ('dont', 'NN'),
#   ('act', 'NN'),
#   ('react', 'JJ'),
#   ('realist', 'NN'),
#   ('stare', 'NN'),
#   ('someth', 'VBZ'),
#   ('like', 'IN'),
#   ('braindead', 'JJ'),
#   ('zombi', 'NN'),
#   ('like', 'IN'),
#   ('friend', 'NN'),
#   ('get', 'VBP'),
#   ('kill', 'VB'),
#   ('right', 'JJ'),
#   ('front', 'NN'),
#   ('whilst', 'NN'),
#   ('hold', 'VBP'),
#   ('gun', 'NN'),
#   ('freek', 'JJ'),
#   ('hand', 'NN'),
#   ('realli', 'NN'),
#   ('terribl', 'NN'),
#   ('scriptplot', 'NN'),
#   ('writingoveral', 'JJ'),
#   ('movi', 'NN'),
#   ('isnt', 'NN'),
#   ('bad', 'JJ'),
#   ('antman', 'NN'),
#   ('2', 'CD'),
#   ('far', 'RB'),
#   ('behind', 'IN'),
#   ('also', 'RB'),
#   ('awkwafina', 'JJ'),
#   ('act', 'NN'),
#   ('style', 'NN'),
#   ('alreadi', 'VBP'),
#   ('old', 'JJ'),
#   ('2nd', 'CD'),
#   ('movi', 'NN'),
#   ('charact', 'NN'),
#   ('movi', 'FW'),
#   ('person', 'NN'),
#   ('like', 'IN'),
#   ('said', 'VBD'),
#   ('got', 'VBD'),
#   ('bore', 'RB'),
#   ('2nd', 'CD'),
#   ('movi', 'NN'),
#   ('roll', 'NN'),
#   ('eye', 'NN'),
#   ('everyth', 'VBP'),
#   ('awkwafina', 'JJ'),
#   ('charact', 'NN'),
#   ('movieit', 'VBD'),
#   ('510', 'CD'),
#   ('movi', 'NN'),
#   ('realli', 'NN'),
#   ('worth', 'JJ'),
#   ('watch', 'NN'),
#   ('unless', 'IN'),
#   ('your', 'PRP$'),
#   ('real', 'JJ'),
#   ('diehard', 'JJ'),
#   ('marvel', 'NN'),
#   ('fan', 'NN')],
#  [('rate', 'NN'),
#   ('810', 'CD'),
#   ('languag', 'NN'),
#   ('english', 'JJ'),
#   ('sourc', 'NN'),
#   ('hotstar', 'NN'),
#   ('recommendedth', 'NN'),
#   ('stori', 'NNS'),
#   ('make', 'VBP'),
#   ('worth', 'JJ'),
#   ('watch', 'NN'),
#   ('big', 'JJ'),
#   ('screen', 'NN'),
#   ('good', 'JJ'),
#   ('sound', 'NN'),
#   ('system', 'NN'),
#   ('first', 'JJ'),
#   ('half', 'NN'),
#   ('fill', 'NN'),
#   ('great', 'JJ'),
#   ('action', 'NN'),
#   ('funni', 'NN'),
#   ('moment', 'NN'),
#   ('get', 'VB'),
#   ('seriou', 'JJ'),
#   ('mode', 'JJ'),
#   ('second', 'JJ'),
#   ('halfth', 'JJ'),
#   ('second', 'JJ'),
#   ('half', 'NN'),
#   ('tradit', 'NN'),
#   ('sentimentalth', 'NN'),
#   ('decent', 'NN'),
#   ('stori', 'FW'),
#   ('colour', 'VBP'),
#   ('visual', 'JJ'),
#   ('make', 'NN'),
#   ('grand', 'JJ'),
#   ('good', 'JJ'),
#   ('movi', 'NN'),
#   ('watch', 'NN'),
#   ('famili', 'NN')],
#  [('martial', 'JJ'),
#   ('art', 'NN'),
#   ('meet', 'NN'),
#   ('mcu', 'JJ'),
#   ('shangchand', 'NN'),
#   ('legend', 'VBP'),
#   ('ten', 'JJ'),
#   ('ring', 'NN'),
#   ('crouch', 'JJ'),
#   ('tiger', 'NN'),
#   ('jacki', 'NN'),
#   ('chan', 'NN'),
#   ('plot', 'NN'),
#   ('film', 'NN'),
#   ('kinda', 'NN'),
#   ('humdrum', 'NN'),
#   ('sort', 'NN'),
#   ('mystic', 'JJ'),
#   ('eastern', 'JJ'),
#   ('fantasi', 'NN'),
#   ('cobbler', 'NN'),
#   ('practic', 'JJ'),
#   ('write', 'NN'),
#   ('itselfshangchi', 'NNS'),
#   ('son', 'VBP'),
#   ('immort', 'NN'),
#   ('powerhungri', 'NN'),
#   ('warlord', 'NN'),
#   ('xu', 'NNP'),
#   ('wenwu', 'VBZ'),
#   ('toni', 'JJ'),
#   ('chiuwaleung', 'NN'),
#   ('lfala', 'NN'),
#   ('chen', 'NN'),
#   ('warrior', 'JJ'),
#   ('woman', 'NN'),
#   ('hidden', 'JJ'),
#   ('villag', 'NN'),
#   ('ta', 'NN'),
#   ('lo', 'VBP'),
#   ('fall', 'NN'),
#   ('love', 'NN'),
#   ('land', 'NN'),
#   ('becom', 'NN'),
#   ('father', 'NN'),
#   ('wenwu', 'NN'),
#   ('give', 'VBP'),
#   ('wick', 'JJ'),
#   ('way', 'NN'),
#   ('pack', 'VB'),
#   ('away', 'RB'),
#   ('ten', 'JJ'),
#   ('legendari', 'JJ'),
#   ('ring', 'VBG'),
#   ('gave', 'VBD'),
#   ('much', 'JJ'),
#   ('power', 'NN'),
#   ('howev', 'NN'),
#   ('wife', 'NN'),
#   ('kill', 'VB'),
#   ('old', 'JJ'),
#   ('enemi', 'NN'),
#   ('wenwu', 'NN'),
#   ('wear', 'IN'),
#   ('ring', 'VBG'),
#   ('train', 'NN'),
#   ('son', 'NN'),
#   ('becom', 'NN'),
#   ('assassin', 'NN'),
#   ('asham', 'NN'),
#   ('becom', 'NN'),
#   ('shangchgo', 'NN'),
#   ('hide', 'NN'),
#   ('america', 'IN'),
#   ('becom', 'NN'),
#   ('shaun', 'NN'),
#   ('simu', 'NN'),
#   ('liu', 'NN'),
#   ('past', 'IN'),
#   ('eventu', 'NN'),
#   ('catch', 'NN'),
#   ('father', 'NN'),
#   ('send', 'NN'),
#   ('armi', 'NN'),
#   ('ten', 'IN'),
#   ('ring', 'VBG'),
#   ('steal', 'JJ'),
#   ('pendant', 'JJ'),
#   ('given', 'VBN'),
#   ('sister', 'RBR'),
#   ('xial', 'JJ'),
#   ('menger', 'NN'),
#   ('zhang', 'NN'),
#   ('mother', 'NN'),
#   ('wenwu', 'NN'),
#   ('requir', 'NN'),
#   ('pendant', 'JJ'),
#   ('reveal', 'JJ'),
#   ('way', 'NN'),
#   ('ta', 'NN'),
#   ('lo', 'JJ'),
#   ('belief', 'JJ'),
#   ('wife', 'NN'),
#   ('held', 'VBD'),
#   ('captiv', 'JJ'),
#   ('peoplethi', 'NN'),
#   ('marvel', 'NN'),
#   ('movi', 'NN'),
#   ('fun', 'NN'),
#   ('plot', 'NN'),
#   ('start', 'VB'),
#   ('get', 'VB'),
#   ('way', 'NN'),
#   ('cgbecom', 'NN'),
#   ('overbear', 'IN'),
#   ('intrus', 'JJ'),
#   ('earli', 'JJ'),
#   ('fight', 'NN'),
#   ('scene', 'NN'),
#   ('battl', 'VBP'),
#   ('runaway', 'RB'),
#   ('bu', 'JJ'),
#   ('henchman', 'NN'),
#   ('known', 'VBN'),
#   ('razor', 'JJ'),
#   ('fist', 'NN'),
#   ('fight', 'NN'),
#   ('highris', 'NN'),
#   ('bamboo', 'NN'),
#   ('scaffold', 'VBD'),
#   ('deliv', 'NN'),
#   ('lot', 'NN'),
#   ('impress', 'JJ'),
#   ('choreograph', 'NN'),
#   ('action', 'NN'),
#   ('pleas', 'IN'),
#   ('martial', 'JJ'),
#   ('art', 'NN'),
#   ('fan', 'NN'),
#   ('superhero', 'NN'),
#   ('addict', 'JJ'),
#   ('awkwafina', 'NN'),
#   ('shangchi', 'NN'),
#   ('loyal', 'JJ'),
#   ('friend', 'NN'),
#   ('kati', 'NN'),
#   ('provid', 'VBP'),
#   ('comic', 'JJ'),
#   ('relief', 'NN'),
#   ('also', 'RB'),
#   ('get', 'VB'),
#   ('stuck', 'JJ'),
#   ('actionunfortun', 'NN'),
#   ('film', 'NN'),
#   ('quickli', 'NN'),
#   ('go', 'VB'),
#   ('downhil', 'RB'),
#   ('good', 'JJ'),
#   ('guy', 'NNS'),
#   ('make', 'VBP'),
#   ('way', 'NN'),
#   ('ta', 'NN'),
#   ('lo', 'NN'),
#   ('littl', 'NN'),
#   ('help', 'NN'),
#   ('toni', 'VB'),
#   ('slatteri', 'JJ'),
#   ('see', 'NN'),
#   ('iron', 'NN'),
#   ('man', 'NN'),
#   ('3', 'CD'),
#   ('furri', 'JJ'),
#   ('wing', 'VBG'),
#   ('creatur', 'JJ'),
#   ('face', 'NN'),
#   ('inevit', 'NN'),
#   ('battl', 'NN'),
#   ('villag', 'NN'),
#   ('wenwu', 'NN'),
#   ('armi', 'NN'),
#   ('typic', 'NN'),
#   ('overblown', 'IN'),
#   ('marvel', 'NN'),
#   ('mayhem', 'NN'),
#   ('massiv', 'NN'),
#   ('cgtsunamarr', 'NN'),
#   ('wenwu', 'NN'),
#   ('open', 'JJ'),
#   ('interdimension', 'NN'),
#   ('gate', 'NN'),
#   ('think', 'VBP'),
#   ('hold', 'VB'),
#   ('lprison', 'JJ'),
#   ('instead', 'RB'),
#   ('releas', 'JJ'),
#   ('wife', 'NN'),
#   ('free', 'JJ'),
#   ('swarm', 'NN'),
#   ('fli', 'NN'),
#   ('tentacl', 'NN'),
#   ('soulsuck', 'VBD'),
#   ('big', 'JJ'),
#   ('bad', 'JJ'),
#   ('bo', 'NN'),
#   ('dweller', 'NN'),
#   ('fortun', 'NN'),
#   ('ta', 'NN'),
#   ('lo', 'NN'),
#   ('peopl', 'NN'),
#   ('massiv', 'NN'),
#   ('magic', 'JJ'),
#   ('dragon', 'JJ'),
#   ('side', 'NN'),
#   ('wake', 'NN'),
#   ('add', 'VBP'),
#   ('digit', 'JJ'),
#   ('whizzbangerya', 'NN'),
#   ('technic', 'JJ'),
#   ('impress', 'NN'),
#   ('special', 'JJ'),
#   ('effect', 'NN'),
#   ('found', 'VBD'),
#   ('second', 'JJ'),
#   ('half', 'NN'),
#   ('film', 'NN'),
#   ('visual', 'JJ'),
#   ('overwhelm', 'NN'),
#   ('yet', 'RB'),
#   ('remark', 'JJ'),
#   ('uninvolv', 'JJ'),
#   ('whirlwind', 'NN'),
#   ('pixel', 'NN'),
#   ('noisi', 'JJ'),
#   ('action', 'NN'),
#   ('without', 'IN'),
#   ('much', 'JJ'),
#   ('substance510', 'NN'),
#   ('nice', 'JJ'),
#   ('see', 'NN'),
#   ('hkchines', 'NNS'),
#   ('star', 'VBD'),
#   ('michel', 'JJ'),
#   ('yeoh', 'NN'),
#   ('toni', 'NN'),
#   ('leung', 'NN'),
#   ('yuen', 'VBP'),
#   ('wah', 'NN'),
#   ('togeth', 'NNS'),
#   ('marvel', 'VBP'),
#   ('movi', 'JJ'),
#   ('wish', 'JJ'),
#   ('better', 'JJR'),
#   ('one', 'NN')],
#  [('shangchand', 'NN'),
#   ('legend', 'NN'),
#   ('ten', 'VBZ'),
#   ('ring', 'VBG'),
#   ('take', 'VB'),
#   ('place', 'NN'),
#   ('time', 'NN'),
#   ('aveng', 'NN'),
#   ('endgam', 'NN'),
#   ('begin', 'VB'),
#   ('phase', 'IN'),
#   ('four', 'CD'),
#   ('marvel', 'NN'),
#   ('cinemat', 'NN'),
#   ('universeshangchi', 'JJ'),
#   ('alright', 'JJ'),
#   ('movi', 'NN'),
#   ('great', 'JJ'),
#   ('fight', 'JJ'),
#   ('scene', 'NN'),
#   ('incred', 'VBD'),
#   ('fight', 'JJ'),
#   ('choreographi', 'NN'),
#   ('epic', 'RB'),
#   ('largescal', 'JJ'),
#   ('battl', 'NN'),
#   ('also', 'RB'),
#   ('good', 'JJ'),
#   ('comed', 'VBD'),
#   ('scene', 'NN'),
#   ('made', 'VBN'),
#   ('laugh', 'IN'),
#   ('coupl', 'JJ'),
#   ('time', 'NN'),
#   ('shangchsuff', 'JJ'),
#   ('come', 'NN'),
#   ('plot', 'NN'),
#   ('didnt', 'NN'),
#   ('find', 'VBP'),
#   ('stori', 'JJ'),
#   ('compel', 'NN'),
#   ('didnt', 'NN'),
#   ('get', 'VB'),
#   ('attach', 'JJ'),
#   ('charact', 'NN'),
#   ('stori', 'NN'),
#   ('feel', 'VB'),
#   ('done', 'VBN'),
#   ('mani', 'JJ'),
#   ('time', 'NN'),
#   ('beforeshangchwasnt', 'NN'),
#   ('comedi', 'NN'),
#   ('fight', 'VBD'),
#   ('scene', 'NN'),
#   ('make', 'VBP'),
#   ('flaw', 'NN'),
#   ('familiar', 'JJ'),
#   ('marvel', 'NN'),
#   ('franchis', 'NN'),
#   ('assum', 'VBZ'),
#   ('somewhat', 'RB'),
#   ('know', 'JJ'),
#   ('expect', 'VBP'),
#   ('recommend', 'VBP'),
#   ('although', 'IN'),
#   ('movi', 'NN'),
#   ('isnt', 'NN'),
#   ('great', 'JJ'),
#   ('still', 'RB'),
#   ('think', 'VBP'),
#   ('good', 'JJ'),
#   ('enough', 'RB'),
#   ('point', 'NN'),
#   ('worth', 'JJ'),
#   ('watch', 'NN'),
#   ('keep', 'VB'),
#   ('larger', 'JJR'),
#   ('plot', 'NN'),
#   ('mcu', 'NN'),
#   ('invest', 'VBP'),
#   ('mcu', 'NN'),
#   ('dont', 'NN'),
#   ('believ', 'NN'),
#   ('movi', 'VBP'),
#   ('one', 'CD'),
#   ('start', 'NN')],
#  [('best', 'JJS'),
#   ('marvel', 'NN'),
#   ('movi', 'NN'),
#   ('endgam', 'NN'),
#   ('stori', 'JJ'),
#   ('bit', 'NN'),
#   ('cliché', 'JJ'),
#   ('rest', 'NN'),
#   ('absolut', 'NN'),
#   ('amaz', 'NN'),
#   ('fight', 'VBD'),
#   ('scene', 'NN'),
#   ('best', 'JJS'),
#   ('mcu', 'JJ'),
#   ('opinion', 'NN'),
#   ('simu', 'NN'),
#   ('liu', 'NN'),
#   ('shangchi', 'JJ'),
#   ('perfectli', 'NN'),
#   ('chosen', 'VBN'),
#   ('charact', 'JJ'),
#   ('nice', 'JJ'),
#   ('actor', 'NN'),
#   ('good', 'JJ'),
#   ('job', 'NN'),
#   ('act', 'NN'),
#   ('3', 'CD'),
#   ('anoth', 'DT'),
#   ('level', 'NN'),
#   ('havent', 'NN'),
#   ('seen', 'VBN'),
#   ('mcu', 'JJ'),
#   ('visual', 'JJ'),
#   ('effect', 'NN'),
#   ('spectacular', 'NN'),
#   ('far', 'RB'),
#   ('one', 'CD'),
#   ('best', 'JJS'),
#   ('origin', 'NN'),
#   ('stori', 'NN'),
#   ('marvel', 'NN')],
#  [('potenti', 'NNS'),
#   ('marvel', 'VBP'),
#   ('tendenc', 'JJ'),
#   ('degrad', 'NN'),
#   ('everyth', 'NN'),
#   ('mindless', 'NN'),
#   ('comedyth', 'NN'),
#   ('happen', 'VB'),
#   ('extent', 'NN'),
#   ('awkwafina', 'IN'),
#   ('aveng', 'NN'),
#   ('im', 'NN'),
#   ('get', 'VBP'),
#   ('old', 'JJ'),
#   ('st', 'NN')],
#  [('realli', 'NN'),
#   ('entertain', 'NN'),
#   ('movi', 'JJ'),
#   ('actor', 'NN'),
#   ('great', 'JJ'),
#   ('simu', 'NN'),
#   ('liu', 'NN'),
#   ('brought', 'VBD'),
#   ('big', 'JJ'),
#   ('time', 'NN'),
#   ('excel', 'NN'),
#   ('main', 'JJ'),
#   ('charact', 'NN'),
#   ('awkwafina', 'IN'),
#   ('hilari', 'JJ'),
#   ('wish', 'JJ'),
#   ('screen', 'NN'),
#   ('time', 'NN'),
#   ('far', 'RB'),
#   ('marvel', 'JJ'),
#   ('movi', 'NNS'),
#   ('go', 'VBP'),
#   ('best', 'RB'),
#   ('one', 'CD'),
#   ('still', 'RB'),
#   ('good', 'JJ')],
#  [('stori', 'NNS'),
#   ('ten', 'VBP'),
#   ('ring', 'VBG'),
#   ('weapon', 'NN'),
#   ('use', 'NN'),
#   ('thousand', 'CD'),
#   ('year', 'NN'),
#   ('take', 'VB'),
#   ('power', 'NN'),
#   ('control', 'NN'),
#   ('shang', 'NN'),
#   ('ch', 'NN'),
#   ('simu', 'NN'),
#   ('liu', 'NN'),
#   ('chang', 'NN'),
#   ('x', 'NNP'),
#   ('accident', 'NN'),
#   ('get', 'VB'),
#   ('pull', 'JJ'),
#   ('histori', 'NN'),
#   ('cant', 'NN'),
#   ('turn', 'VBP'),
#   ('back', 'RP'),
#   ('costar', 'JJ'),
#   ('awkwafina', 'NN'),
#   ('toni', 'NN'),
#   ('leung', 'NN'),
#   ('winner', 'IN'),
#   ('ton', 'NN'),
#   ('film', 'NN'),
#   ('festiv', 'NN'),
#   ('award', 'NN'),
#   ('also', 'RB'),
#   ('ben', 'JJ'),
#   ('kingsley', 'NN'),
#   ('oscar', 'NN'),
#   ('gandhalthough', 'JJ'),
#   ('look', 'NN'),
#   ('differ', 'NN'),
#   ('may', 'MD'),
#   ('recogn', 'VB'),
#   ('kingsley', 'VB'),
#   ('role', 'NN'),
#   ('marvel', 'NN'),
#   ('stori', 'FW'),
#   ('disney', 'NN'),
#   ('there', 'RB'),
#   ('good', 'JJ'),
#   ('mix', 'NN'),
#   ('adventur', 'NN'),
#   ('violenc', 'NN'),
#   ('anim', 'NN'),
#   ('levit', 'NN'),
#   ('joke', 'VBD'),
#   ('sprinkl', 'JJ'),
#   ('bad', 'JJ'),
#   ('guy', 'NN'),
#   ('collect', 'NN'),
#   ('pendant', 'JJ'),
#   ('power', 'NN'),
#   ('allow', 'IN'),
#   ('gether', 'NN'),
#   ('surprisingli', 'NN'),
#   ('coupl', 'NN'),
#   ('swear', 'VBP'),
#   ('give', 'JJ'),
#   ('pg13', 'NN'),
#   ('rate', 'NN'),
#   ('meet', 'NN'),
#   ('good', 'JJ'),
#   ('peopl', 'NN'),
#   ('want', 'VBP'),
#   ('help', 'NN'),
#   ('journey', 'NN'),
#   ('evil', 'JJ'),
#   ('peopl', 'NN'),
#   ('want', 'VBP'),
#   ('destroy', 'NN'),
#   ('fun', 'NN'),
#   ('special', 'JJ'),
#   ('effect', 'NN'),
#   ('direct', 'JJ'),
#   ('destin', 'NN'),
#   ('cretton', 'NN'),
#   ('chang', 'NN'),
#   ('xcharact', 'NNP'),
#   ('creat', 'NN'),
#   ('steve', 'VBP'),
#   ('englehart', 'NN'),
#   ('jim', 'NN'),
#   ('starlin', 'NN'),
#   ('quit', 'VBD'),
#   ('good', 'JJ')],
#  [('realli', 'NNS'),
#   ('like', 'IN'),
#   ('actor', 'NN'),
#   ('spoke', 'VBD'),
#   ('nativ', 'JJ'),
#   ('languag', 'NN'),
#   ('mandarin', 'NN'),
#   ('wouldv', 'NN'),
#   ('felt', 'VBD'),
#   ('american', 'JJ'),
#   ('otherwis', 'NN'),
#   ('someth', 'VBD'),
#   ('unfinish', 'JJ'),
#   ('movi', 'NN'),
#   ('im', 'NN'),
#   ('sure', 'JJ'),
#   ('pace', 'NN'),
#   ('alright', 'VBD'),
#   ('littl', 'JJ'),
#   ('slow', 'JJ'),
#   ('fast', 'NN'),
#   ('time', 'NN'),
#   ('far', 'RB'),
#   ('storylin', 'RB'),
#   ('go', 'VBP'),
#   ('excit', 'JJ'),
#   ('thought', 'NN'),
#   ('would', 'MD'),
#   ('fight', 'VB'),
#   ('scene', 'NN'),
#   ('great', 'JJ'),
#   ('though', 'IN'),
#   ('especi', 'JJ'),
#   ('final', 'JJ'),
#   ('grand', 'JJ'),
#   ('battl', 'NN'),
#   ('scene', 'NN')],
#  [('worst', 'JJS'),
#   ('marvel', 'NN'),
#   ('movi', 'NN'),
#   ('seen', 'VBN'),
#   ('dateaft', 'NN'),
#   ('see', 'NN'),
#   ('movi', 'JJ'),
#   ('honestli', 'NN'),
#   ('surpris', 'JJ'),
#   ('high', 'JJ'),
#   ('rate', 'NN'),
#   ('watch', 'NN'),
#   ('thing', 'NN'),
#   ('movi', 'NN'),
#   ('without', 'IN'),
#   ('soul', 'NN'),
#   ('charact', 'NN'),
#   ('arent', 'JJ'),
#   ('build', 'NN'),
#   ('enough', 'JJ'),
#   ('even', 'RB'),
#   ('2', 'CD'),
#   ('hour', 'NN'),
#   ('run', 'NN'),
#   ('time', 'NN'),
#   ('movi', 'JJ'),
#   ('liter', 'NN'),
#   ('got', 'VBD'),
#   ('noth', 'DT'),
#   ('ten', 'JJ'),
#   ('ring', 'NN'),
#   ('movi', 'NN'),
#   ('becam', 'NN'),
#   ('godzilla', 'NN'),
#   ('v', 'IN'),
#   ('king', 'VBG'),
#   ('kong', 'JJ'),
#   ('end', 'NN'),
#   ('wast', 'VBD'),
#   ('2', 'CD'),
#   ('hour', 'NN'),
#   ('honestli', 'NN'),
#   ('clueless', 'NN'),
#   ('peopl', 'NN'),
#   ('high', 'JJ'),
#   ('prais', 'NN'),
#   ('movi', 'NN'),
#   ('wast', 'NN'),
#   ('opportun', 'NN'),
#   ('creat', 'NN'),
#   ('wonder', 'VBP'),
#   ('authent', 'JJ'),
#   ('world', 'NN'),
#   ('asian', 'JJ'),
#   ('marvel', 'NN'),
#   ('univers', 'NNS')]]

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**
